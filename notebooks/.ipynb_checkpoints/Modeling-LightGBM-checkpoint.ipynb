# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import os

import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm_notebook
from sklearn.preprocessing import StandardScaler
from sklearn.svm import NuSVR, SVR
from sklearn.metrics import mean_absolute_error
pd.options.display.precision = 15

import lightgbm as lgb
import xgboost as xgb
import time
import datetime
from catboost import CatBoostRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold, GroupKFold, GridSearchCV, train_test_split, TimeSeriesSplit
from sklearn import metrics
from sklearn import linear_model
import gc
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

import eli5
import shap
from IPython.display import HTML
import json
import altair as alt
import pickle

import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

alt.renderers.enable('notebook')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# RendererRegistry.enable('notebook')

# %%
main_path = r'../..'

# %%
import sys
sys.path.append(main_path)
from BayDS import *
# from lib.training import plot_importance
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-02f3c5fd87ed> in <module>
#       2 sys.path.append(main_path)
#       3 from BayDS import *
# ----> 4 from lib.training import plot_importance
#
# ModuleNotFoundError: No module named 'lib.training'

# %%
experiment_name = '31.08'
main_learning_folder = main_path+'/Snapshots/'+experiment_name

# %%
train = pd.read_pickle(f'{main_learning_folder}/train.pkl')
test = pd.read_pickle(f'{main_learning_folder}/test.pkl')

# %%
X = train.sort_values('TransactionDT').drop(['isFraud', 'TransactionDT'], axis=1)
y = train.sort_values('TransactionDT')['isFraud'].astype(np.uint8)
test = test.sort_values('TransactionDT').drop(['TransactionDT'], axis=1)

X.drop('Date', axis=1, inplace=True)
X=X.astype(np.float32)
test.drop('Date', axis=1, inplace=True)
test=test.astype(np.float32)
del train
gc.collect()
# Out:
# 28

# %%
space_lgb = {
    'num_leaves': np.arange(10, 100, 30),
    'min_child_weight': np.arange(1, 300, 80),
    'learning_rate': [np.float32(0.01)],
    'max_bin': np.arange(9, 40, 1),
    'lambda_l1': np.arange(0, 3, 1), 
    'lambda_l2': np.arange(0, 3, 1),
    'min_data_in_leaf' : np.arange(5, 250, 90),
    'min_sum_hessian_in_leaf' : np.arange(0.0001, 0.01, 0.005),
    'bagging_fraction' : np.arange(0.1, 0.9, 0.3),
    'max_bin': np.arange(10, 30, 10),
    'feature_fraction' : np.arange(0.1, 0.9, 0.3),
    'bagging_freq' : np.arange(200, 1000, 400),
    'min_gain_to_split': np.arange(0.1, 1, 0.3),     
}
import itertools
result = list(itertools.product(*space_lgb.values()))
import random
random.seed(77)
random.shuffle(result)

# %%
num_experiments = len(result)
for it,r in enumerate(result):
    if it == 0:
        continue
    gc.collect()
    print(f'######################\n{it}/{num_experiments}')
    tuned_params_lgb = {k:r[i].item() for i,k in enumerate(space_lgb.keys())}
    print(tuned_params_lgb)
    # Setting model_folder
    model_name = 'lightgbm-%04d'%it
    model_folder = f'{main_learning_folder}/{model_name}'
    if not os.path.exists(model_folder):
        os.makedirs(model_folder)
    n_fold = 5
    # folds = TimeSeriesSplit(n_splits=n_fold)
    folds = KFold(n_splits=n_fold)
    # folds = GroupKFold(n_splits=5)
    # groups = pd.read_pickle('./groups.pkl').values
    
    params = { **tuned_params_lgb,
          'objective': 'binary',
          'max_depth': -1,
          "boosting_type": "gbdt",
          "bagging_seed": 11,
          "metric": 'auc',
          "verbosity": -1,
          'reg_alpha': 0.3899927210061127,
          'reg_lambda': 0.6485237330340494,
          'random_state': 47,
#           'device': 'gpu'
         }
    train_options = {
        "model_type":'lgb',
        "params": params,
        "eval_metric":'auc',
        'early_stopping_rounds': 500,
        'n_estimators': 10000,
        'averaging': 'usual',
        'use_groups': False,
        'fold_name': folds.__class__.__name__,
        'n_splits': n_fold
    }
    with open(f'{model_folder}/training_params.json', 'w') as f:
        q = json.dumps(train_options,indent=2)
        f.write(q)
    
    result_dict_lgb = train_model_classification(X=X, X_test=test, y=y, params=params, folds=folds,
                                             model_type=train_options['model_type'], 
                                             eval_metric=train_options['eval_metric'],
                                             plot_feature_importance=True,
                                             verbose=500, early_stopping_rounds=train_options['early_stopping_rounds'],
                                             n_estimators=train_options['n_estimators'], 
                                             averaging=train_options['averaging'],
                                             n_jobs=-1, groups=None)
    # plt.savefig(f'{learning_folder}/feature_importance.png')

    plot_importance(result_dict_lgb,f'{model_folder}/feature_importance.png')
    
    with open(f'{model_folder}/results_dict.pkl', 'wb') as f:
    #     q = json.dumps(result_dict_lgb,indent=2)
        pickle.dump(result_dict_lgb,f)
    #     f.write(q)
# Out:
# ######################
# 0/69984
# {'num_leaves': 40, 'min_child_weight': 241, 'learning_rate': 0.009999999776482582, 'max_bin': 20, 'lambda_l1': 1, 'lambda_l2': 1, 'min_data_in_leaf': 185, 'min_sum_hessian_in_leaf': 0.0051, 'bagging_fraction': 0.1, 'feature_fraction': 0.1, 'bagging_freq': 200, 'min_gain_to_split': 0.1}
# Fold 1 started at Sun Sep  1 12:32:27 2019
# Training until validation scores don't improve for 500 rounds.
# [500]	training's auc: 0.915515	training's auc: 0.915515	valid_1's auc: 0.870681	valid_1's auc: 0.870681
# [1000]	training's auc: 0.935953	training's auc: 0.935953	valid_1's auc: 0.882798	valid_1's auc: 0.882798
# [1500]	training's auc: 0.948368	training's auc: 0.948368	valid_1's auc: 0.892394	valid_1's auc: 0.892394
# [2000]	training's auc: 0.955698	training's auc: 0.955698	valid_1's auc: 0.896836	valid_1's auc: 0.896836
# [2500]	training's auc: 0.961447	training's auc: 0.961447	valid_1's auc: 0.898683	valid_1's auc: 0.898683
# [3000]	training's auc: 0.96628	training's auc: 0.96628	valid_1's auc: 0.900903	valid_1's auc: 0.900903
# [3500]	training's auc: 0.970467	training's auc: 0.970467	valid_1's auc: 0.901454	valid_1's auc: 0.901454
# [4000]	training's auc: 0.972938	training's auc: 0.972938	valid_1's auc: 0.902678	valid_1's auc: 0.902678
# Early stopping, best iteration is:
# [3784]	training's auc: 0.972283	training's auc: 0.972283	valid_1's auc: 0.904641	valid_1's auc: 0.904641
# Fold 2 started at Sun Sep  1 12:47:59 2019
# Training until validation scores don't improve for 500 rounds.
# [500]	training's auc: 0.914358	training's auc: 0.914358	valid_1's auc: 0.894123	valid_1's auc: 0.894123
# [1000]	training's auc: 0.934018	training's auc: 0.934018	valid_1's auc: 0.903227	valid_1's auc: 0.903227
# [1500]	training's auc: 0.94632	training's auc: 0.94632	valid_1's auc: 0.910012	valid_1's auc: 0.910012
# [2000]	training's auc: 0.954438	training's auc: 0.954438	valid_1's auc: 0.913947	valid_1's auc: 0.913947
# [2500]	training's auc: 0.959325	training's auc: 0.959325	valid_1's auc: 0.928745	valid_1's auc: 0.928745
# [3000]	training's auc: 0.964181	training's auc: 0.964181	valid_1's auc: 0.931209	valid_1's auc: 0.931209
# [3500]	training's auc: 0.96864	training's auc: 0.96864	valid_1's auc: 0.932752	valid_1's auc: 0.932752
# [4000]	training's auc: 0.972042	training's auc: 0.972042	valid_1's auc: 0.9336	valid_1's auc: 0.9336
# [4500]	training's auc: 0.975571	training's auc: 0.975571	valid_1's auc: 0.934243	valid_1's auc: 0.934243
# [5000]	training's auc: 0.977651	training's auc: 0.977651	valid_1's auc: 0.936019	valid_1's auc: 0.936019
# [5500]	training's auc: 0.980381	training's auc: 0.980381	valid_1's auc: 0.936038	valid_1's auc: 0.936038
# [6000]	training's auc: 0.982571	training's auc: 0.982571	valid_1's auc: 0.937328	valid_1's auc: 0.937328
# Early stopping, best iteration is:
# [5937]	training's auc: 0.982404	training's auc: 0.982404	valid_1's auc: 0.937358	valid_1's auc: 0.937358
# Fold 5 started at Sun Sep  1 13:47:26 2019
# Training until validation scores don't improve for 500 rounds.
# [500]	training's auc: 0.914617	training's auc: 0.914617	valid_1's auc: 0.885952	valid_1's auc: 0.885952
# [1000]	training's auc: 0.93511	training's auc: 0.93511	valid_1's auc: 0.898488	valid_1's auc: 0.898488
# [1500]	training's auc: 0.947634	training's auc: 0.947634	valid_1's auc: 0.90591	valid_1's auc: 0.90591
# [2000]	training's auc: 0.955782	training's auc: 0.955782	valid_1's auc: 0.908388	valid_1's auc: 0.908388
# [2500]	training's auc: 0.960833	training's auc: 0.960833	valid_1's auc: 0.910958	valid_1's auc: 0.910958
# [3000]	training's auc: 0.965456	training's auc: 0.965456	valid_1's auc: 0.911849	valid_1's auc: 0.911849
# [3500]	training's auc: 0.97019	training's auc: 0.97019	valid_1's auc: 0.913405	valid_1's auc: 0.913405
# [4000]	training's auc: 0.973301	training's auc: 0.973301	valid_1's auc: 0.914384	valid_1's auc: 0.914384
# [4500]	training's auc: 0.976671	training's auc: 0.976671	valid_1's auc: 0.915438	valid_1's auc: 0.915438
# [5000]	training's auc: 0.978647	training's auc: 0.978647	valid_1's auc: 0.915945	valid_1's auc: 0.915945
# [5500]	training's auc: 0.981047	training's auc: 0.981047	valid_1's auc: 0.917093	valid_1's auc: 0.917093
# [6000]	training's auc: 0.982874	training's auc: 0.982874	valid_1's auc: 0.916882	valid_1's auc: 0.916882
# Early stopping, best iteration is:
# [5822]	training's auc: 0.98214	training's auc: 0.98214	valid_1's auc: 0.917929	valid_1's auc: 0.917929
# CV mean score: 0.9214, std: 0.0106.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-94829beb5b8b> in <module>
#      57     with open(f'{model_folder}/results_dict.pkl', 'wb') as f:
#      58     #     q = json.dumps(result_dict_lgb,indent=2)
# ---> 59         pickle.dump(result_dict_lgb,f)
#      60     #     f.write(q)
#
# NameError: name 'pickle' is not defined
