# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import os
import pickle

import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm_notebook
from sklearn.preprocessing import StandardScaler
from sklearn.svm import NuSVR, SVR
from sklearn.metrics import mean_absolute_error
pd.options.display.precision = 15

import lightgbm as lgb
import xgboost as xgb
import time
import datetime
from catboost import CatBoostRegressor
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold, GroupKFold, GridSearchCV, train_test_split, TimeSeriesSplit
from sklearn import metrics
from sklearn import linear_model
import gc
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

import eli5
import shap
from IPython.display import HTML
import json
import altair as alt

import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

alt.renderers.enable('notebook')

# %%
# with pd.HDFStore('./hdf/Store.h5',complib='blosc:blosclz') as store:
#     data = store['initial/encoded']
#     categorial_features = list(store['initial/categorial_features'].values.flatten())
#     numerical_features = list(store['initial/numerical_features'].values.flatten())
#     numerical_features.sort()
#     categorial_features.sort()
data = pd.read_pickle("./pickles/data_all_features.pkl")

# %%
fraud = data['isFraud']
fraud = fraud.replace({'test':-1})
fraud = fraud.astype(np.int8)
data['isFraud'] = fraud

# %%
# with pd.HDFStore('./hdf/Store.h5',complib='blosc:blosclz') as store:
#     categorial_features = list(store['initial/categorial_features'].values.flatten())
#     numerical_features = list(store['initial/numerical_features'].values.flatten())
categorial_features = json.load(open('pickles/categorial_features.json','r'))
numerical_features = json.load(open('pickles/numerical_features.json','r'))

# %% [markdown]
# ## Apply Additional Features

# %%
with pd.HDFStore('./hdf/Store.h5',complib='blosc:blosclz') as store:
    num_features = store.get_node('encodedFeatures')
    for feature in num_features:
        feature_name = feature._v_name
        # here would be assession of feature introduction
        q = store.select(feature._v_pathname)
        if len(q[q.index.duplicated()]) != 0:
            print('Problem', feature_name)
            q.drop(q[q.index.duplicated()].index, axis=0, inplace=True)
        data[feature_name] = q
    numerical_features += ['BrowserAge', 'BrowserVersion', 'screen_height', 'screen_width']
    categorial_features +=  ['Browser',  'OS', 'OSVersion', 'device_name', 'device_version']
    
categorial_features.remove('id_30')
categorial_features.remove('id_31')
data.drop(['id_30','id_31'], axis=1, inplace=True)

# %%
data.head()

# %%
## Load CardId
with pd.HDFStore('./hdf/Store.h5',complib='blosc:blosclz') as store:
    data['card_id'] = store['initial/card_id']
categorial_features.append('card_id')

# %%
data.head()

# %%
data.drop(['R_emaildomain','P_emaildomain'], axis=1,inplace=True)

# %% [markdown]
# # Other features

# %%
data['TransactionAmt_decimal'] = ((data['TransactionAmt'] - data['TransactionAmt'].astype(int)) * 1000).astype(int)
with pd.HDFStore('./hdf/engineering.h5') as store:
    store['numerical/TransactionAmt_decimal'] = data[['TransactionAmt_decimal']]

# %%
data['card1_count_full'] = data['card1'].map(data['card1'].value_counts(dropna=False))
with pd.HDFStore('./hdf/engineering.h5') as store:
    store['numerical/card1_count_full'] = data[['card1_count_full']]

# %%
# Some arbitrary features interaction
for feature in ['id_02__id_20', 'id_02__D8', 'D11__device_name', 'device_name__P_emaildomain_bin', 'P_emaildomain_bin__C2', 
                'card2__dist1', 'card1__card5', 'card2__id_20', 'card5__P_emaildomain_bin', 'addr1__card1']:
    print(feature)
    f1, f2 = feature.split('__')
    data[feature] = data[f1].astype(str) + '_' + data[f2].astype(str)

#     le = LabelEncoderPopularity(convert_nan=True)
#     le.fit(data[feature].astype(str))
#     data[feature] = le.transform(data[feature].astype(str))
    with pd.HDFStore('./hdf/engineering.h5') as store:
        store[f'categorial/{feature}'] = data[[feature]]

# %%
categorial_features += ['id_02__id_20', 'id_02__D8', 'D11__device_name', 'device_name__P_emaildomain_bin', 'P_emaildomain_bin__C2', 
                'card2__dist1', 'card1__card5', 'card2__id_20', 'card5__P_emaildomain_bin', 'addr1__card1']

# %%
for feature in  ['id_01', 'id_33', 'id_35', 'id_34', 'id_36']:
        # Count encoded for both train and test
        data[feature + '_count_full'] = data[feature].map(data[feature].value_counts(dropna=False))
        with pd.HDFStore('./hdf/engineering.h5') as store:
            store[f'numerical/{feature}_count_full'] = data[[feature + '_count_full']   ]
        
    
# for feature in ['id_34', 'id_36']:
#         # Count encoded for both train and test
#         data[feature + '_count_full'] = data[feature].map(data[feature].value_counts(dropna=False))
        
# for feature in ['id_01', 'id_31', 'id_33', 'id_35', 'id_36']:
#     if feature in useful_features:
#         # Count encoded separately for train and test
#         train[feature + '_count_dist'] = train[feature].map(train[feature].value_counts(dropna=False))
#         test[feature + '_count_dist'] = test[feature].map(test[feature].value_counts(dropna=False))

# %% [markdown]
# ## Label encode categorial Features

# %%
from functions import LabelEncoderNan
for col in categorial_features:
    if col in data.columns:
        le = LabelEncoderNan()
        le.fit(list(data[col].map(lambda x: str(x).lower()).values))
        data[col] = le.transform(list(data[col].map(lambda x: str(x).lower()).values))

# %%
with pd.HDFStore('./hdf/pre-aggregate.h5') as store:
    store[f'data'] = data

# %%
from lib.training import train_model_classification
def quick_score2(data, categorial_features, addition=None, categorial_features_in_addition=None, target='isFraud', drop_columns=['Date'], filter_neg_target=True,
                 params=None, n_estimators = 6):
    if params is None:
        params = {'num_leaves': 500,
                  'min_child_weight': 0.03454472573214212,
                  'feature_fraction': 0.3797454081646243,
                  'bagging_fraction': 0.4181193142567742,
                  'min_data_in_leaf': 106,
                  'objective': 'binary',
                  'max_depth': -1,
                  'learning_rate': 0.1,
                  "boosting_type": "gbdt",
                  "bagging_seed": 11,
                  "metric": 'auc',
                  "verbosity": -1,
                  'reg_alpha': 0.3899927210061127,
                  'reg_lambda': 0.6485237330340494,
                  'random_state': 47,
                  }

    if filter_neg_target:
        train_subset_ids = data[data[target] >= 0].index
    else:
        train_subset_ids = data.index

    X_new = data.loc[train_subset_ids].drop(drop_columns + [target], axis=1)
    if addition is not None:
        X_new = X_new.join(addition.loc[train_subset_ids])
        if categorial_features_in_addition is not None:
            categorial_features.extend(categorial_features_in_addition)

    y = data.loc[train_subset_ids][target].astype(np.bool)

    folds = KFold(n_splits=5, shuffle=False)


    categorical_columns = [c for c, col in enumerate(X_new.columns) if col in categorial_features]

    params['categorical_feature'] = categorical_columns

    results = train_model_classification(X=X_new, X_test=None, y=y, params=params, folds=folds, splits=1,
                                         model_type='lgb', eval_metric='auc', plot_feature_importance=False,
                                         verbose=None, early_stopping_rounds=40, n_estimators=600, averaging='usual',
                                         n_jobs=-1)

    return sum(results['scores']) / len(results['scores'])

# %%
score = quick_score2(data,categorial_features,drop_columns=['Date','card_id'])
print ("Main score is ", score)
# Out:
# Fold 5 started at Sat Aug 24 20:42:42 2019
# CV mean score: 0.9117, std: 0.0000.
# Main score is  0.9116769852711911

# %% [markdown]
# # Aggregates

# %%
def add_numerical_aggregate(df, target_column, group_column, scoring=True, save=True):
    print(target_column, group_column)
    to_mean = pd.DataFrame()
    to_mean[f'{target_column}_to_mean_{group_column}'] = df[target_column] / data.groupby([group_column])[target_column].transform('mean')
    if scoring:
        new_score = quick_score2(df,categorial_features,addition=to_mean,categorial_features_in_addition=[])
        delta_score = new_score - score
        with open('./hdf/num_agg_scores.csv','a') as f:
            f.write(f'{target_column}_to_mean_{group_column}, {delta_score}\n')
    if save:
        with pd.HDFStore('./hdf/engineering.h5') as store:
            store[f'numerical/{target_column}_to_std_{group_column}'] = to_mean[[f'{target_column}_to_mean_{group_column}']]

    to_std = pd.DataFrame()
    to_std[f'{target_column}_to_std_{group_column}'] = df[target_column] / data.groupby([group_column])[target_column].transform('std')
    if scoring:
        new_score = quick_score2(df,categorial_features,addition=to_std,categorial_features_in_addition=[])
        delta_score = new_score - score
        with open('./hdf/num_agg_scores.csv','a') as f:
            f.write(f'{target_column}_to_std_{group_column}, {delta_score}\n')
    if save:
        with pd.HDFStore('./hdf/engineering.h5') as store:
            store[f'numerical/{target_column}_to_std_{group_column}'] = to_std[[f'{target_column}_to_std_{group_column}']]
    return to_mean.join(to_std)
    
# add_numerical_aggregate(data,'TransactionAmt', 'card_id')
# add_numerical_aggregate(data,'dist1', 'card_id')
# add_numerical_aggregate(data,'_Hours', 'card_id')

# %%
started = False
for num_feature in numerical_features:
    if not started and num_feature != 'V1':
        continue
    started = True
    for cat_feature in ['card_id']:
        try:
            add_numerical_aggregate(data,num_feature, cat_feature)
        except Exception as ex:
            print('Exception', ex)
# Out:
# V1 card_id
# Exception 'V1'
# V2 card_id
# Exception 'V2'
# V3 card_id
# Fold 5 started at Sat Aug 24 22:28:14 2019
# CV mean score: 0.9134, std: 0.0000.
# Fold 5 started at Sat Aug 24 22:30:34 2019
# CV mean score: 0.9130, std: 0.0000.
# V4 card_id
# Fold 5 started at Sat Aug 24 22:32:34 2019
# CV mean score: 0.9120, std: 0.0000.
# Fold 5 started at Sat Aug 24 22:34:48 2019
# CV mean score: 0.9118, std: 0.0000.
# V5 card_id
# Fold 5 started at Sat Aug 24 22:37:09 2019
# CV mean score: 0.9123, std: 0.0000.
# Fold 5 started at Sat Aug 24 22:39:44 2019
# CV mean score: 0.9140, std: 0.0000.
# V6 card_id
# Fold 5 started at Sat Aug 24 22:41:35 2019
# CV mean score: 0.9122, std: 0.0000.
# Fold 5 started at Sat Aug 24 22:43:19 2019
# CV mean score: 0.9116, std: 0.0000.
# V7 card_id
# Fold 5 started at Sat Aug 24 22:45:21 2019
# CV mean score: 0.9124, std: 0.0000.
# Fold 5 started at Sat Aug 24 22:47:11 2019
# CV mean score: 0.9136, std: 0.0000.
# V8 card_id
# Fold 5 started at Sat Aug 24 22:49:24 2019
# CV mean score: 0.9132, std: 0.0000.
# Fold 5 started at Sat Aug 24 22:51:14 2019
# CV mean score: 0.9129, std: 0.0000.
# V9 card_id
# Fold 5 started at Sat Aug 24 22:53:46 2019
# CV mean score: 0.9141, std: 0.0000.
# Fold 5 started at Sat Aug 24 22:55:34 2019
# CV mean score: 0.9123, std: 0.0000.
# V10 card_id
# Fold 5 started at Sat Aug 24 22:57:27 2019
# CV mean score: 0.9134, std: 0.0000.
# Fold 5 started at Sat Aug 24 22:59:13 2019
# CV mean score: 0.9121, std: 0.0000.
# V11 card_id
# Fold 5 started at Sat Aug 24 23:00:56 2019
# CV mean score: 0.9137, std: 0.0000.
# Fold 5 started at Sat Aug 24 23:02:37 2019
# CV mean score: 0.9134, std: 0.0000.
# V12 card_id
# Fold 5 started at Sat Aug 24 23:04:37 2019
# CV mean score: 0.9120, std: 0.0000.
# Fold 5 started at Sat Aug 24 23:06:29 2019
# CV mean score: 0.9135, std: 0.0000.
# V13 card_id
# Fold 5 started at Sat Aug 24 23:11:06 2019
# CV mean score: 0.9129, std: 0.0000.
# Fold 5 started at Sat Aug 24 23:13:01 2019
# CV mean score: 0.9123, std: 0.0000.
# V14 card_id
# Exception 'V14'
# V15 card_id
# Exception 'V15'
# V16 card_id
# Exception 'V16'
# V17 card_id
# Fold 5 started at Sat Aug 24 23:15:26 2019
# CV mean score: 0.9143, std: 0.0000.
# Fold 5 started at Sat Aug 24 23:17:36 2019
# CV mean score: 0.9133, std: 0.0000.
# V18 card_id
# Exception 'V18'
# V19 card_id
# Fold 5 started at Sat Aug 24 23:19:58 2019
# CV mean score: 0.9133, std: 0.0000.
# Fold 5 started at Sat Aug 24 23:21:43 2019
# CV mean score: 0.9128, std: 0.0000.
# V20 card_id
# Fold 5 started at Sat Aug 24 23:23:32 2019
# CV mean score: 0.9139, std: 0.0000.
# Fold 5 started at Sat Aug 24 23:25:29 2019
# CV mean score: 0.9121, std: 0.0000.
# V21 card_id
# Exception 'V21'
# V22 card_id
# Exception 'V22'
# V23 card_id
# Exception 'V23'
# V24 card_id
# Exception 'V24'
# V25 card_id
# Exception 'V25'
# V26 card_id
# Exception 'V26'
# V27 card_id
# Exception 'V27'
# V28 card_id
# Exception 'V28'
# V29 card_id
# Fold 5 started at Sat Aug 24 23:28:35 2019
# CV mean score: 0.9133, std: 0.0000.
# Fold 5 started at Sat Aug 24 23:30:37 2019
# CV mean score: 0.9133, std: 0.0000.
# V30 card_id
# Fold 5 started at Sat Aug 24 23:33:17 2019
# CV mean score: 0.9138, std: 0.0000.
# Fold 5 started at Sat Aug 24 23:35:10 2019
# CV mean score: 0.9133, std: 0.0000.
# V31 card_id
# Exception 'V31'
# V32 card_id
# Exception 'V32'
# V33 card_id
# Fold 5 started at Sat Aug 24 23:37:21 2019
# CV mean score: 0.9119, std: 0.0000.
# Fold 5 started at Sat Aug 24 23:39:27 2019
# CV mean score: 0.9113, std: 0.0000.
# V34 card_id
# Fold 5 started at Sat Aug 24 23:41:18 2019
# CV mean score: 0.9126, std: 0.0000.
# Fold 5 started at Sat Aug 24 23:43:32 2019
# CV mean score: 0.9130, std: 0.0000.
# V35 card_id
# Fold 5 started at Sat Aug 24 23:46:15 2019
# CV mean score: 0.9127, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1546, in H5F_open
#     unable to open file: time = Sat Aug 24 23:47:44 2019
# , name = './hdf/engineering.h5', tent_flags = 1
#   File "C:\ci\hdf5_1545244154871\work\src\H5FD.c", line 734, in H5FD_open
#     open failed
#   File "C:\ci\hdf5_1545244154871\work\src\H5FDsec2.c", line 346, in H5FD_sec2_open
#     unable to open file: name = './hdf/engineering.h5', errno = 13, error message = 'Permission denied', flags = 1, o_flags = 2
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V36 card_id
# Fold 5 started at Sat Aug 24 23:47:57 2019
# CV mean score: 0.9145, std: 0.0000.
# Fold 5 started at Sat Aug 24 23:49:45 2019
# CV mean score: 0.9122, std: 0.0000.
# V37 card_id
# Fold 5 started at Sat Aug 24 23:51:55 2019
# CV mean score: 0.9138, std: 0.0000.
# Fold 5 started at Sat Aug 24 23:53:52 2019
# CV mean score: 0.9128, std: 0.0000.
# V38 card_id
# Fold 5 started at Sat Aug 24 23:55:30 2019
# CV mean score: 0.9108, std: 0.0000.
# Fold 5 started at Sat Aug 24 23:58:21 2019
# CV mean score: 0.9141, std: 0.0000.
# V39 card_id
# Exception 'V39'
# V40 card_id
# Fold 5 started at Sun Aug 25 00:02:00 2019
# CV mean score: 0.9148, std: 0.0000.
# Fold 5 started at Sun Aug 25 00:03:32 2019
# CV mean score: 0.9139, std: 0.0000.
# V41 card_id
# Exception 'V41'
# V42 card_id
# Exception 'V42'
# V43 card_id
# Exception 'V43'
# V44 card_id
# Fold 5 started at Sun Aug 25 00:06:40 2019
# CV mean score: 0.9138, std: 0.0000.
# Fold 5 started at Sun Aug 25 00:08:28 2019
# CV mean score: 0.9128, std: 0.0000.
# V45 card_id
# Fold 5 started at Sun Aug 25 00:10:22 2019
# CV mean score: 0.9146, std: 0.0000.
# Fold 5 started at Sun Aug 25 00:12:54 2019
# CV mean score: 0.9135, std: 0.0000.
# V46 card_id
# Fold 5 started at Sun Aug 25 00:14:50 2019
# CV mean score: 0.9131, std: 0.0000.
# Fold 5 started at Sun Aug 25 00:17:05 2019
# CV mean score: 0.9125, std: 0.0000.
# V47 card_id
# Fold 5 started at Sun Aug 25 00:20:37 2019
# CV mean score: 0.9136, std: 0.0000.
# Fold 5 started at Sun Aug 25 00:23:03 2019
# CV mean score: 0.9128, std: 0.0000.
# V48 card_id
# Fold 5 started at Sun Aug 25 00:25:47 2019
# CV mean score: 0.9132, std: 0.0000.
# Fold 5 started at Sun Aug 25 00:30:35 2019
# CV mean score: 0.9146, std: 0.0000.
# V49 card_id
# Fold 5 started at Sun Aug 25 00:33:01 2019
# CV mean score: 0.9106, std: 0.0000.
# Fold 5 started at Sun Aug 25 00:35:22 2019
# CV mean score: 0.9138, std: 0.0000.
# V50 card_id
# Exception 'V50'
# V51 card_id
# Fold 5 started at Sun Aug 25 00:37:54 2019
# CV mean score: 0.9131, std: 0.0000.
# Fold 5 started at Sun Aug 25 00:39:59 2019
# CV mean score: 0.9129, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1546, in H5F_open
#     unable to open file: time = Sun Aug 25 00:42:04 2019
# , name = './hdf/engineering.h5', tent_flags = 1
#   File "C:\ci\hdf5_1545244154871\work\src\H5FD.c", line 734, in H5FD_open
#     open failed
#   File "C:\ci\hdf5_1545244154871\work\src\H5FDsec2.c", line 346, in H5FD_sec2_open
#     unable to open file: name = './hdf/engineering.h5', errno = 13, error message = 'Permission denied', flags = 1, o_flags = 2
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V52 card_id
# Fold 5 started at Sun Aug 25 00:42:19 2019
# CV mean score: 0.9130, std: 0.0000.
# Fold 5 started at Sun Aug 25 00:45:06 2019
# CV mean score: 0.9149, std: 0.0000.
# V53 card_id
# Fold 5 started at Sun Aug 25 00:47:38 2019
# CV mean score: 0.9126, std: 0.0000.
# Fold 5 started at Sun Aug 25 00:49:41 2019
# CV mean score: 0.9119, std: 0.0000.
# V54 card_id
# Fold 5 started at Sun Aug 25 00:51:41 2019
# CV mean score: 0.9146, std: 0.0000.
# Fold 5 started at Sun Aug 25 00:53:54 2019
# CV mean score: 0.9132, std: 0.0000.
# V55 card_id
# Exception 'V55'
# V56 card_id
# Fold 5 started at Sun Aug 25 00:55:46 2019
# CV mean score: 0.9121, std: 0.0000.
# Fold 5 started at Sun Aug 25 00:57:35 2019
# CV mean score: 0.9120, std: 0.0000.
# V57 card_id
# Exception 'V57'
# V58 card_id
# Fold 5 started at Sun Aug 25 00:59:33 2019
# CV mean score: 0.9128, std: 0.0000.
# Fold 5 started at Sun Aug 25 01:02:26 2019
# CV mean score: 0.9109, std: 0.0000.
# V59 card_id
# Fold 5 started at Sun Aug 25 01:04:00 2019
# CV mean score: 0.9141, std: 0.0000.
# Fold 5 started at Sun Aug 25 01:07:24 2019
# CV mean score: 0.9123, std: 0.0000.
# V60 card_id
# Fold 5 started at Sun Aug 25 01:10:30 2019
# CV mean score: 0.9123, std: 0.0000.
# Fold 5 started at Sun Aug 25 01:12:19 2019
# CV mean score: 0.9116, std: 0.0000.
# V61 card_id
# Fold 5 started at Sun Aug 25 01:14:14 2019
# CV mean score: 0.9140, std: 0.0000.
# Fold 5 started at Sun Aug 25 01:17:19 2019
# CV mean score: 0.9108, std: 0.0000.
# V62 card_id
# Fold 5 started at Sun Aug 25 01:19:38 2019
# CV mean score: 0.9125, std: 0.0000.
# Fold 5 started at Sun Aug 25 01:21:35 2019
# CV mean score: 0.9108, std: 0.0000.
# V63 card_id
# Fold 5 started at Sun Aug 25 01:23:40 2019
# CV mean score: 0.9122, std: 0.0000.
# Fold 5 started at Sun Aug 25 01:26:18 2019
# CV mean score: 0.9108, std: 0.0000.
# V64 card_id
# Fold 5 started at Sun Aug 25 01:28:07 2019
# CV mean score: 0.9128, std: 0.0000.
# Fold 5 started at Sun Aug 25 01:30:39 2019
# CV mean score: 0.9132, std: 0.0000.
# V65 card_id
# Exception 'V65'
# V66 card_id
# Exception 'V66'
# V67 card_id
# Exception 'V67'
# V68 card_id
# Exception 'V68'
# V69 card_id
# Fold 5 started at Sun Aug 25 01:33:37 2019
# CV mean score: 0.9127, std: 0.0000.
# Fold 5 started at Sun Aug 25 01:35:33 2019
# CV mean score: 0.9110, std: 0.0000.
# V70 card_id
# Fold 5 started at Sun Aug 25 01:36:53 2019
# CV mean score: 0.9138, std: 0.0000.
# Fold 5 started at Sun Aug 25 01:38:36 2019
# CV mean score: 0.9143, std: 0.0000.
# V71 card_id
# Fold 5 started at Sun Aug 25 01:41:35 2019
# CV mean score: 0.9144, std: 0.0000.
# Fold 5 started at Sun Aug 25 01:43:48 2019
# CV mean score: 0.9124, std: 0.0000.
# V72 card_id
# Fold 5 started at Sun Aug 25 01:46:45 2019
# CV mean score: 0.9133, std: 0.0000.
# Fold 5 started at Sun Aug 25 01:49:51 2019
# CV mean score: 0.9127, std: 0.0000.
# V73 card_id
# Fold 5 started at Sun Aug 25 01:52:03 2019
# CV mean score: 0.9134, std: 0.0000.
# Fold 5 started at Sun Aug 25 01:53:47 2019
# CV mean score: 0.9123, std: 0.0000.
# V74 card_id
# Fold 5 started at Sun Aug 25 01:55:43 2019
# CV mean score: 0.9125, std: 0.0000.
# Fold 5 started at Sun Aug 25 01:58:36 2019
# CV mean score: 0.9124, std: 0.0000.
# V75 card_id
# Fold 5 started at Sun Aug 25 02:00:34 2019
# CV mean score: 0.9116, std: 0.0000.
# Fold 5 started at Sun Aug 25 02:02:24 2019
# CV mean score: 0.9117, std: 0.0000.
# V76 card_id
# Fold 5 started at Sun Aug 25 02:06:14 2019
# CV mean score: 0.9106, std: 0.0000.
# Fold 5 started at Sun Aug 25 02:08:18 2019
# CV mean score: 0.9135, std: 0.0000.
# V77 card_id
# Exception 'V77'
# V78 card_id
# Fold 5 started at Sun Aug 25 02:11:05 2019
# CV mean score: 0.9124, std: 0.0000.
# Fold 5 started at Sun Aug 25 02:13:10 2019
# CV mean score: 0.9133, std: 0.0000.
# V79 card_id
# Exception 'V79'
# V80 card_id
# Fold 5 started at Sun Aug 25 02:14:58 2019
# CV mean score: 0.9127, std: 0.0000.
# Fold 5 started at Sun Aug 25 02:17:17 2019
# CV mean score: 0.9130, std: 0.0000.
# V81 card_id
# Fold 5 started at Sun Aug 25 02:19:34 2019
# CV mean score: 0.9099, std: 0.0000.
# Fold 5 started at Sun Aug 25 02:21:00 2019
# CV mean score: 0.9139, std: 0.0000.
# V82 card_id
# Fold 5 started at Sun Aug 25 02:23:28 2019
# CV mean score: 0.9137, std: 0.0000.
# Fold 5 started at Sun Aug 25 02:25:38 2019
# CV mean score: 0.9130, std: 0.0000.
# V83 card_id
# Fold 5 started at Sun Aug 25 02:27:18 2019
# CV mean score: 0.9123, std: 0.0000.
# Exception Problems creating the Array.
# V84 card_id
# Fold 5 started at Sun Aug 25 02:29:09 2019
# CV mean score: 0.9120, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1546, in H5F_open
#     unable to open file: time = Sun Aug 25 02:30:55 2019
# , name = './hdf/engineering.h5', tent_flags = 1
#   File "C:\ci\hdf5_1545244154871\work\src\H5FD.c", line 734, in H5FD_open
#     open failed
#   File "C:\ci\hdf5_1545244154871\work\src\H5FDsec2.c", line 346, in H5FD_sec2_open
#     unable to open file: name = './hdf/engineering.h5', errno = 13, error message = 'Permission denied', flags = 1, o_flags = 2
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V85 card_id
# Fold 5 started at Sun Aug 25 02:31:08 2019
# CV mean score: 0.9105, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V86 card_id
# Exception 'V86'
# V87 card_id
# Fold 5 started at Sun Aug 25 02:33:00 2019
# CV mean score: 0.9133, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V88 card_id
# Exception 'V88'
# V89 card_id
# Exception 'V89'
# V90 card_id
# Fold 5 started at Sun Aug 25 02:35:03 2019
# CV mean score: 0.9125, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V91 card_id
# Fold 5 started at Sun Aug 25 02:36:52 2019
# CV mean score: 0.9133, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V92 card_id
# Fold 5 started at Sun Aug 25 02:38:36 2019
# CV mean score: 0.9103, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V93 card_id
# Fold 5 started at Sun Aug 25 02:40:03 2019
# CV mean score: 0.9130, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
# Unable to open/create file './hdf/engineering.h5'
# V94 card_id
# Fold 5 started at Sun Aug 25 02:42:42 2019
# CV mean score: 0.9130, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V95 card_id
# Fold 5 started at Sun Aug 25 02:44:37 2019
# CV mean score: 0.9137, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V96 card_id
# Fold 5 started at Sun Aug 25 02:46:48 2019
# CV mean score: 0.9145, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V97 card_id
# Fold 5 started at Sun Aug 25 02:49:19 2019
# CV mean score: 0.9125, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V98 card_id
# Exception 'V98'
# V99 card_id
# Fold 5 started at Sun Aug 25 02:51:29 2019
# CV mean score: 0.9141, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V100 card_id
# Fold 5 started at Sun Aug 25 02:53:45 2019
# CV mean score: 0.9139, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V101 card_id
# Exception 'V101'
# V102 card_id
# Exception 'V102'
# V103 card_id
# Exception 'V103'
# V104 card_id
# Exception 'V104'
# V105 card_id
# Exception 'V105'
# V106 card_id
# Exception 'V106'
# V107 card_id
# Exception 'V107'
# V108 card_id
# Exception 'V108'
# V109 card_id
# Exception 'V109'
# V110 card_id
# Exception 'V110'
# V111 card_id
# Exception 'V111'
# V112 card_id
# Exception 'V112'
# V113 card_id
# Exception 'V113'
# V114 card_id
# Exception 'V114'
# V115 card_id
# Exception 'V115'
# V116 card_id
# Exception 'V116'
# V117 card_id
# Exception 'V117'
# V118 card_id
# Exception 'V118'
# V119 card_id
# Exception 'V119'
# V120 card_id
# Exception 'V120'
# V121 card_id
# Exception 'V121'
# V122 card_id
# Exception 'V122'
# V123 card_id
# Exception 'V123'
# V124 card_id
# Exception 'V124'
# V125 card_id
# Exception 'V125'
# V126 card_id
# Fold 5 started at Sun Aug 25 02:55:50 2019
# CV mean score: 0.9140, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V127 card_id
# Fold 5 started at Sun Aug 25 02:58:15 2019
# CV mean score: 0.9127, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V128 card_id
# Fold 5 started at Sun Aug 25 03:00:14 2019
# CV mean score: 0.9120, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V129 card_id
# Exception 'V129'
# V130 card_id
# Fold 5 started at Sun Aug 25 03:02:09 2019
# CV mean score: 0.9114, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V131 card_id
# Fold 5 started at Sun Aug 25 03:05:21 2019
# CV mean score: 0.9124, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
# Unable to open/create file './hdf/engineering.h5'
# V132 card_id
# Exception 'V132'
# V133 card_id
# Exception 'V133'
# V134 card_id
# Exception 'V134'
# V135 card_id
# Exception 'V135'
# V136 card_id
# Exception 'V136'
# V137 card_id
# Exception 'V137'
# V138 card_id
# Fold 5 started at Sun Aug 25 03:07:10 2019
# CV mean score: 0.9136, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V139 card_id
# Fold 5 started at Sun Aug 25 03:09:03 2019
# CV mean score: 0.9139, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V140 card_id
# Fold 5 started at Sun Aug 25 03:10:58 2019
# CV mean score: 0.9144, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V141 card_id
# Exception 'V141'
# V142 card_id
# Exception 'V142'
# V143 card_id
# Fold 5 started at Sun Aug 25 03:13:34 2019
# CV mean score: 0.9124, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V144 card_id
# Exception 'V144'
# V145 card_id
# Fold 5 started at Sun Aug 25 03:15:23 2019
# CV mean score: 0.9138, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V146 card_id
# Fold 5 started at Sun Aug 25 03:20:11 2019
# CV mean score: 0.9123, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V147 card_id
# Fold 5 started at Sun Aug 25 03:22:17 2019
# CV mean score: 0.9127, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V148 card_id
# Exception 'V148'
# V149 card_id
# Fold 5 started at Sun Aug 25 03:24:06 2019
# CV mean score: 0.9120, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V150 card_id
# Fold 5 started at Sun Aug 25 03:25:46 2019
# CV mean score: 0.9128, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V151 card_id
# Fold 5 started at Sun Aug 25 03:28:43 2019
# CV mean score: 0.9124, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V152 card_id
# Fold 5 started at Sun Aug 25 03:30:45 2019
# CV mean score: 0.9112, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V153 card_id
# Exception 'V153'
# V154 card_id
# Fold 5 started at Sun Aug 25 03:32:36 2019
# CV mean score: 0.9127, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
# Unable to open/create file './hdf/engineering.h5'
# V155 card_id
# Exception 'V155'
# V156 card_id
# Fold 5 started at Sun Aug 25 03:36:02 2019
# CV mean score: 0.9152, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V157 card_id
# Exception 'V157'
# V158 card_id
# Fold 5 started at Sun Aug 25 03:37:54 2019
# CV mean score: 0.9131, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V159 card_id
# Fold 5 started at Sun Aug 25 03:41:15 2019
# CV mean score: 0.9117, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V160 card_id
# Fold 5 started at Sun Aug 25 03:43:25 2019
# CV mean score: 0.9136, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V161 card_id
# Fold 5 started at Sun Aug 25 03:45:56 2019
# CV mean score: 0.9107, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V162 card_id
# Fold 5 started at Sun Aug 25 03:48:45 2019
# CV mean score: 0.9110, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V163 card_id
# Fold 5 started at Sun Aug 25 03:50:58 2019
# CV mean score: 0.9125, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V164 card_id
# Fold 5 started at Sun Aug 25 03:52:44 2019
# CV mean score: 0.9131, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V165 card_id
# Fold 5 started at Sun Aug 25 03:54:18 2019
# CV mean score: 0.9125, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V166 card_id
# Fold 5 started at Sun Aug 25 03:57:49 2019
# CV mean score: 0.9120, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V167 card_id
# Fold 5 started at Sun Aug 25 04:00:21 2019
# CV mean score: 0.9137, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V168 card_id
# Exception 'V168'
# V169 card_id
# Fold 5 started at Sun Aug 25 04:02:26 2019
# CV mean score: 0.9134, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
# Unable to open/create file './hdf/engineering.h5'
# V170 card_id
# Fold 5 started at Sun Aug 25 04:05:19 2019
# CV mean score: 0.9124, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V171 card_id
# Fold 5 started at Sun Aug 25 04:07:02 2019
# CV mean score: 0.9147, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V172 card_id
# Fold 5 started at Sun Aug 25 04:09:35 2019
# CV mean score: 0.9121, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V173 card_id
# Fold 5 started at Sun Aug 25 04:11:30 2019
# CV mean score: 0.9125, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V174 card_id
# Exception 'V174'
# V175 card_id
# Fold 5 started at Sun Aug 25 04:14:04 2019
# CV mean score: 0.9128, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V176 card_id
# Fold 5 started at Sun Aug 25 04:16:22 2019
# CV mean score: 0.9129, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V177 card_id
# Fold 5 started at Sun Aug 25 04:18:28 2019
# CV mean score: 0.9135, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V178 card_id
# Fold 5 started at Sun Aug 25 04:20:14 2019
# CV mean score: 0.9129, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V179 card_id
# Exception 'V179'
# V180 card_id
# Fold 5 started at Sun Aug 25 04:22:50 2019
# CV mean score: 0.9118, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# V181 card_id
# Exception 'V181'
# V182 card_id
# Fold 5 started at Sun Aug 25 04:26:04 2019
# CV mean score: 0.9128, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
# ...
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# C3 card_id
# Exception 'C3'
# C4 card_id
# Fold 5 started at Sun Aug 25 09:00:41 2019
# CV mean score: 0.9125, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# C5 card_id
# Fold 5 started at Sun Aug 25 09:02:38 2019
# CV mean score: 0.9145, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# C6 card_id
# Fold 5 started at Sun Aug 25 09:05:32 2019
# CV mean score: 0.9144, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# C7 card_id
# Fold 5 started at Sun Aug 25 09:07:28 2019
# CV mean score: 0.9127, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# C8 card_id
# Fold 5 started at Sun Aug 25 09:09:39 2019
# CV mean score: 0.9115, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# C9 card_id
# Fold 5 started at Sun Aug 25 09:12:45 2019
# CV mean score: 0.9148, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# C10 card_id
# Fold 5 started at Sun Aug 25 09:14:29 2019
# CV mean score: 0.9139, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# C11 card_id
# Fold 5 started at Sun Aug 25 09:16:50 2019
# CV mean score: 0.9108, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# C12 card_id
# Fold 5 started at Sun Aug 25 09:18:25 2019
# CV mean score: 0.9114, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# C13 card_id
# Fold 5 started at Sun Aug 25 09:21:32 2019
# CV mean score: 0.9131, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# C14 card_id
# Fold 5 started at Sun Aug 25 09:23:10 2019
# CV mean score: 0.9140, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# dist1 card_id
# Fold 5 started at Sun Aug 25 09:26:01 2019
# CV mean score: 0.9131, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1546, in H5F_open
#     unable to open file: time = Sun Aug 25 09:27:35 2019
# , name = './hdf/engineering.h5', tent_flags = 1
#   File "C:\ci\hdf5_1545244154871\work\src\H5FD.c", line 734, in H5FD_open
#     open failed
#   File "C:\ci\hdf5_1545244154871\work\src\H5FDsec2.c", line 346, in H5FD_sec2_open
#     unable to open file: name = './hdf/engineering.h5', errno = 13, error message = 'Permission denied', flags = 1, o_flags = 2
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# TransactionAmt card_id
# Fold 5 started at Sun Aug 25 09:27:53 2019
# CV mean score: 0.9130, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1546, in H5F_open
#     unable to open file: time = Sun Aug 25 09:29:23 2019
# , name = './hdf/engineering.h5', tent_flags = 1
#   File "C:\ci\hdf5_1545244154871\work\src\H5FD.c", line 734, in H5FD_open
#     open failed
#   File "C:\ci\hdf5_1545244154871\work\src\H5FDsec2.c", line 346, in H5FD_sec2_open
#     unable to open file: name = './hdf/engineering.h5', errno = 13, error message = 'Permission denied', flags = 1, o_flags = 2
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# NanIdentityCount card_id
# Fold 5 started at Sun Aug 25 09:29:36 2019
# CV mean score: 0.9128, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# NanTransactionCount card_id
# Fold 5 started at Sun Aug 25 09:32:02 2019
# CV mean score: 0.9125, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
# Unable to open/create file './hdf/engineering.h5'
# _Weekdays card_id
# Fold 5 started at Sun Aug 25 09:35:34 2019
# CV mean score: 0.9129, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# _Hours card_id
# Fold 5 started at Sun Aug 25 09:37:31 2019
# CV mean score: 0.9114, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# _Days card_id
# Fold 5 started at Sun Aug 25 09:40:25 2019
# CV mean score: 0.9142, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# Date card_id
# Exception No numeric types to aggregate
# dist2 card_id
# Exception 'dist2'
# BrowserAge card_id
# Fold 5 started at Sun Aug 25 09:42:47 2019
# CV mean score: 0.9124, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1546, in H5F_open
#     unable to open file: time = Sun Aug 25 09:44:09 2019
# , name = './hdf/engineering.h5', tent_flags = 1
#   File "C:\ci\hdf5_1545244154871\work\src\H5FD.c", line 734, in H5FD_open
#     open failed
#   File "C:\ci\hdf5_1545244154871\work\src\H5FDsec2.c", line 346, in H5FD_sec2_open
#     unable to open file: name = './hdf/engineering.h5', errno = 13, error message = 'Permission denied', flags = 1, o_flags = 2
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# BrowserVersion card_id
# Fold 5 started at Sun Aug 25 09:44:22 2019
# CV mean score: 0.9136, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# screen_height card_id
# Fold 5 started at Sun Aug 25 09:46:48 2019
# CV mean score: 0.9130, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fsuper.c", line 623, in H5F__super_read
#     truncated file: eof = 1660641724, sblock->base_addr = 0, stored_eof = 1669419572
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'
# screen_width card_id
# Fold 5 started at Sun Aug 25 09:48:47 2019
# CV mean score: 0.9139, std: 0.0000.
# Exception HDF5 error back trace
#
#   File "C:\ci\hdf5_1545244154871\work\src\H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "C:\ci\hdf5_1545244154871\work\src\H5Fint.c", line 1546, in H5F_open
#     unable to open file: time = Sun Aug 25 09:50:04 2019
# , name = './hdf/engineering.h5', tent_flags = 1
#   File "C:\ci\hdf5_1545244154871\work\src\H5FD.c", line 734, in H5FD_open
#     open failed
#   File "C:\ci\hdf5_1545244154871\work\src\H5FDsec2.c", line 346, in H5FD_sec2_open
#     unable to open file: name = './hdf/engineering.h5', errno = 13, error message = 'Permission denied', flags = 1, o_flags = 2
#
# End of HDF5 error back trace
#
# Unable to open/create file './hdf/engineering.h5'

# %%
num_aggs = []
started = False
for i,num_feature in enumerate(numerical_features):
    if not started and num_feature != 'V266':
        continue
    started=True
    for cat_feature in ['card_id']:
        try:
            agg_new = add_numerical_aggregate(data,num_feature, cat_feature,scoring=False, save=False)
            num_aggs.append(agg_new)
        except Exception as ex:
            print('Exception', ex)
# Out:
# V266 card_id
# V267 card_id
# V268 card_id
# V269 card_id
# Exception 'V269'
# V270 card_id
# V271 card_id
# V272 card_id
# V273 card_id
# V274 card_id
# V275 card_id
# V276 card_id
# V277 card_id
# V278 card_id
# V279 card_id
# V280 card_id
# V281 card_id
# Exception 'V281'
# V282 card_id
# V283 card_id
# V284 card_id
# Exception 'V284'
# V285 card_id
# V286 card_id
# Exception 'V286'
# V287 card_id
# V288 card_id
# V289 card_id
# V290 card_id
# Exception 'V290'
# V291 card_id
# V292 card_id
# V293 card_id
# Exception 'V293'
# V294 card_id
# V295 card_id
# Exception 'V295'
# V296 card_id
# Exception 'V296'
# V297 card_id
# Exception 'V297'
# V298 card_id
# Exception 'V298'
# V299 card_id
# Exception 'V299'
# V300 card_id
# Exception 'V300'
# V301 card_id
# Exception 'V301'
# V302 card_id
# Exception 'V302'
# V303 card_id
# V304 card_id
# V305 card_id
# Exception 'V305'
# V306 card_id
# V307 card_id
# V308 card_id
# V309 card_id
# Exception 'V309'
# V310 card_id
# V311 card_id
# Exception 'V311'
# V312 card_id
# V313 card_id
# V314 card_id
# V315 card_id
# V316 card_id
# Exception 'V316'
# V317 card_id
# V318 card_id
# Exception 'V318'
# V319 card_id
# Exception 'V319'
# V320 card_id
# Exception 'V320'
# V321 card_id
# Exception 'V321'
# V322 card_id
# V323 card_id
# V324 card_id
# V325 card_id
# Exception 'V325'
# V326 card_id
# V327 card_id
# Exception 'V327'
# V328 card_id
# Exception 'V328'
# V329 card_id
# V330 card_id
# Exception 'V330'
# V331 card_id
# V332 card_id
# V333 card_id
# V334 card_id
# Exception 'V334'
# V335 card_id
# V336 card_id
# V337 card_id
# Exception 'V337'
# V338 card_id
# V339 card_id
# Exception 'V339'
# D1 card_id
# D2 card_id
# D3 card_id
# D4 card_id
# D5 card_id
# D6 card_id
# D7 card_id
# Exception 'D7'
# D8 card_id
# D9 card_id
# D10 card_id
# D11 card_id
# D12 card_id
# D13 card_id
# D14 card_id
# D15 card_id
# C1 card_id
# C2 card_id
# C3 card_id
# Exception 'C3'
# C4 card_id
# C5 card_id
# C6 card_id
# C7 card_id
# C8 card_id
# C9 card_id
# C10 card_id
# C11 card_id
# C12 card_id
# C13 card_id
# C14 card_id
# dist1 card_id
# TransactionAmt card_id
# NanIdentityCount card_id
# NanTransactionCount card_id
# _Weekdays card_id
# _Hours card_id
# _Days card_id
# Date card_id
# Exception No numeric types to aggregate
# dist2 card_id
# Exception 'dist2'
# BrowserAge card_id
# BrowserVersion card_id
# screen_height card_id
# screen_width card_id

# %%
num_agg2 = pd.concat(num_aggs,axis=1)

# %%
num_agg = num_agg.join(num_agg2)

# %%
del num_aggs

# %%
del num_agg2

# %%
import gc
gc.collect()
# Out:
# 17687

# %%
num_agg.head()
# Out:
#                id_01_to_mean_card_id  id_01_to_std_card_id  \
# TransactionID
# 2987000                          NaN                   NaN
# 2987001                          NaN                   NaN
# 2987002                          NaN                   NaN
# 2987003                          NaN                   NaN
# 2987004                         -0.0                   0.0
#
#                id_02_to_mean_card_id  id_02_to_std_card_id  \
# TransactionID
# 2987000                          NaN                   NaN
# 2987001                          NaN                   NaN
# 2987002                          NaN                   NaN
# 2987003                          NaN                   NaN
# 2987004             0.73072261919263     0.924500429290362
#
#                id_03_to_mean_card_id  id_03_to_std_card_id  \
# TransactionID
# 2987000                          NaN                   NaN
# 2987001                          NaN                   NaN
# 2987002                          NaN                   NaN
# 2987003                          NaN                   NaN
# 2987004                          NaN                   NaN
#
#                id_04_to_mean_card_id  id_04_to_std_card_id  \
# TransactionID
# 2987000                          NaN                   NaN
# 2987001                          NaN                   NaN
# 2987002                          NaN                   NaN
# 2987003                          NaN                   NaN
# 2987004                          NaN                   NaN
#
#                id_05_to_mean_card_id  id_05_to_std_card_id  ...  \
# TransactionID                                               ...
# 2987000                          NaN                   NaN  ...
# 2987001                          NaN                   NaN  ...
# 2987002                          NaN                   NaN  ...
# 2987003                          NaN                   NaN  ...
# 2987004                          NaN                   NaN  ...
#
#                _Days_to_mean_card_id  _Days_to_std_card_id  \
# TransactionID
# 2987000            0.142857142857143     0.187977895099228
# 2987001            0.129283489096573     0.230604616442685
# 2987002            0.128579651748453     0.214963126078670
# 2987003            0.131019268553307     0.224939409060347
# 2987004            0.126050420168067     0.222674539986069
#
#                BrowserAge_to_mean_card_id  BrowserAge_to_std_card_id  \
# TransactionID
# 2987000                               NaN                        NaN
# 2987001                               NaN                        NaN
# 2987002                               NaN                        NaN
# 2987003                               NaN                        NaN
# 2987004                               NaN                        NaN
#
#                BrowserVersion_to_mean_card_id  BrowserVersion_to_std_card_id  \
# TransactionID
# 2987000                                   NaN                            NaN
# 2987001                                   NaN                            NaN
# 2987002                                   NaN                            NaN
# 2987003                                   NaN                            NaN
# 2987004                                   NaN                            NaN
#
#                screen_height_to_mean_card_id  screen_height_to_std_card_id  \
# TransactionID
# 2987000                                  NaN                           NaN
# 2987001                                  NaN                           NaN
# 2987002                                  NaN                           NaN
# 2987003                                  NaN                           NaN
# 2987004                    1.034923315048218             8.318767547607422
#
#                screen_width_to_mean_card_id  screen_width_to_std_card_id
# TransactionID
# 2987000                                 NaN                          NaN
# 2987001                                 NaN                          NaN
# 2987002                                 NaN                          NaN
# 2987003                                 NaN                          NaN
# 2987004                   1.225240707397461            7.904130458831787
#
# [5 rows x 514 columns]

# %%
num_agg = num_agg.astype(np.float32)

# %%
with pd.HDFStore('e:/numerical_aggregations.h5',complib='blosc:blosclz') as store:
    store.put('num_agg', num_agg)

# %% [markdown]
# 0) Treat categorial features accurately, find very diverse and unite them
#
# 1) Убрать коррелирующие фичи
#
# 2) Убрать ту из них что даёт меньший джини
#
# 3) TimeKFold instead of StratifiedKFold
