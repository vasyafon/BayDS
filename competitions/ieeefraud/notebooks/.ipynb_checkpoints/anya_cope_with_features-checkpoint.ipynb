# %%
from time import time
import lightgbm as lgb
import numpy as np
import sys
# sys.path.append('..\Python Scripts\pipeline')
import warnings
warnings.filterwarnings('ignore') 
import seaborn as sns
from sklearn import preprocessing
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
import pickle
from sklearn.model_selection import KFold, TimeSeriesSplit
from scipy.stats import uniform
import datetime
from sklearn.ensemble import RandomForestClassifier
import lightgbm
from sklearn.feature_selection import RFECV

from scipy import stats
# from hyperopt import hp, tpe
# from hyperopt.fmin import fmin
from sklearn.model_selection import cross_val_score, StratifiedKFold
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score, GridSearchCV, validation_curve, KFold
from sklearn.metrics import roc_auc_score
import seaborn as sns
# %matplotlib inline
import gc
def reduce_memory_usage(df):
    '''
    iterate through all the columns of a dataframe and modify the data type
    to reduce memory usage.
    '''
    start_mem = df.memory_usage().sum()/1024**2
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if (col_type != object) & (col_type != 'datetime64[ns]'):
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)

    end_mem = df.memory_usage().sum()/1024**2
    print('Memory usage: Before|{:.2f} MB || After|{:.2f} MB || Decreased|{:.1f}%'.format(start_mem, end_mem, 100*(1 - end_mem/start_mem)))
    
    return df 
def missing_values_table(df):
    '''
    Функция возвращает таблицу с количеством и долей пропущенных значений в датафрейме
    '''
    mis_val = df.isnull().sum()
    mis_val_percent = 100 * df.isnull().sum() / len(df)

    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)

    mis_val_table_ren_columns = mis_val_table.rename(
    columns = {0 : 'Missing Values', 1 : '% of Total Values'})

    mis_val_table_ren_columns = mis_val_table_ren_columns[
        mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
    '% of Total Values', ascending=False).round(1)

    print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
        "There are " + str(mis_val_table_ren_columns.shape[0]) +
          " columns that have missing values.")
    return mis_val_table_ren_columns
def reduce_mem_usage(df):
    '''
    iterate through all the columns of a dataframe and modify the data type
    to reduce memory usage.
    '''
    start_mem = df.memory_usage().sum()/1024**2
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if (col_type != object) & (col_type != 'datetime64[ns]'):
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)

    end_mem = df.memory_usage().sum()/1024**2
    print('Memory usage: Before|{:.2f} MB || After|{:.2f} MB || Decreased|{:.1f}%'.format(start_mem, end_mem, 100*(1 - end_mem/start_mem)))
    
    return df

# %%
main_path = r'../..'

import sys
sys.path.append(main_path)
from BayDS import *
# Out:
# Using TensorFlow backend.

# %%
with pd.HDFStore('F:\my\Prog\kaggle\Fraud\hdf\pre-aggregate-no-duplicates.h5') as store:
    data = store[f'data']

train = data[data['isFraud'] != -1]
test = data[data['isFraud'] == -1]

del data
gc.collect()
# Out:
# 55

# %%
X = train.sort_index().drop(['isFraud'], axis=1)
y = train.sort_index()['isFraud'].astype(np.uint8)
test = test.sort_index()

X.drop('Date', axis=1, inplace=True)
X=X.astype(np.float32)
test.drop('Date', axis=1, inplace=True)
test=test.astype(np.float32)

del train
gc.collect()
# Out:
# 49

# %%
# highest = pd.read_csv('f:\my\Prog\kaggle\Baydin\ieee_with_additions.csv')

# %%
params = {'num_leaves': 491,
          'min_child_weight': 0.03454472573214212,
          'feature_fraction': 0.3797454081646243,
          'bagging_fraction': 0.4181193142567742,
          'min_data_in_leaf': 106,
          'objective': 'binary',
          'max_depth': -1,
          'learning_rate': 0.006883242363721497,
          "boosting_type": "gbdt",
          "bagging_seed": 11,
          "metric": 'auc',
          "verbosity": -1,
          'reg_alpha': 0.3899927210061127,
          'reg_lambda': 0.6485237330340494,
          'random_state': 47, 
         }

# %%
n_fold = 5
folds = KFold(n_splits=n_fold)

# %%
train_options = {
    "model_type":'lgb',
    "params": params,
    "eval_metric":'auc',
    'early_stopping_rounds': 200,
    'n_estimators': 2045,
    'averaging': 'usual',
    'use_groups': False,
    'fold_name': folds.__class__.__name__,
    'n_splits': n_fold
    
}

# %%
result_dict_lgb = train_model_classification(X=X, X_test=test, y=y, params=params, folds=folds,
                                             model_type=train_options['model_type'], 
                                             eval_metric=train_options['eval_metric'],
                                             plot_feature_importance=True,
                                             verbose=500, early_stopping_rounds=train_options['early_stopping_rounds'],
                                             n_estimators=train_options['n_estimators'], 
                                             averaging=train_options['averaging'],
                                             n_jobs=-1, groups=None)
# Out:
# Fold 1 started at Tue Sep 10 16:58:13 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's auc: 0.982741	training's auc: 0.982741	valid_1's auc: 0.907948	valid_1's auc: 0.907948
# [1000]	training's auc: 0.996807	training's auc: 0.996807	valid_1's auc: 0.918304	valid_1's auc: 0.918304
# [1500]	training's auc: 0.999462	training's auc: 0.999462	valid_1's auc: 0.920713	valid_1's auc: 0.920713
# [2000]	training's auc: 0.999912	training's auc: 0.999912	valid_1's auc: 0.921042	valid_1's auc: 0.921042
# Early stopping, best iteration is:
# [1844]	training's auc: 0.999847	training's auc: 0.999847	valid_1's auc: 0.921225	valid_1's auc: 0.921225
# Fold 2 started at Tue Sep 10 17:27:08 2019
# Training until validation scores don't improve for 200 rounds.
# [500]	training's auc: 0.982557	training's auc: 0.982557	valid_1's auc: 0.926817	valid_1's auc: 0.926817
# ...

# %%
Xscore = pd.DataFrame(result_dict_lgb['oof'], index=y.index, columns=['score'])

# %%
Xscore.to_csv('oof_best_submit.csv')

# %%
timeaggs = pd.DataFrame(index=y.index)
for i, cat in enumerate(['TransactionAmt', 
                         'C1', 'C2','C5', 'C4', 'C6','C7', 'C8', 'C9', 'C10', 'C11', 'C12', 'C13', 'C14', 
                         'id_02', 'dist1',
                         'D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D8', 'D9', 'D10', 'D11', 'D12', 'D13', 'D14', 'D15']):
    print(i, cat)
    timeaggs = pd.concat([timeaggs, reduce_mem_usage(pd.read_pickle(f'f:/my/Prog/kaggle/Baydin/Data/agg1/{cat}.pkl'))], axis=1)
# Out:
# 0 TransactionAmt
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 1 C1
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 2 C2
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 3 C5
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 4 C4
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 5 C6
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 6 C7
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 7 C8
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 8 C9
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 9 C10
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 10 C11
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 11 C12
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 12 C13
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 13 C14
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 14 id_02
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 15 dist1
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 16 D1
# ...

# %%
aggs = timeaggs.loc[:3577539]

# %%
timeaggs.loc[3577539:].to_csv('test_aggs.csv')

# %%
del aggs, test, timeaggs, Xscore

# %%
del X

# %%
Xscagg = pd.concat([Xscore, aggs], axis=1)

# %%
Xscagg.to_csv('X_score_agg.csv')

# %%
Xscagg.replace(np.inf, -999, inplace=True)
Xscagg.replace(-np.inf, -999, inplace=True)
Xscaggnonan = Xscagg.fillna(-999)

# %%
clf = lgb.LGBMClassifier(**params)
rfe = RFECV(estimator=clf, step=30, cv=KFold(n_splits=4, shuffle=False), scoring='roc_auc', verbose=2)

# %%
rfe.fit(Xscaggnonan, y)
# Out:
# Fitting estimator with 481 features.
# Fitting estimator with 451 features.
# Fitting estimator with 421 features.
# Fitting estimator with 391 features.
# Fitting estimator with 361 features.
# Fitting estimator with 331 features.
# Fitting estimator with 301 features.
# Fitting estimator with 271 features.
# Fitting estimator with 241 features.
# Fitting estimator with 211 features.
# Fitting estimator with 181 features.
# Fitting estimator with 151 features.
# Fitting estimator with 121 features.
# Fitting estimator with 91 features.
# Fitting estimator with 61 features.
# Fitting estimator with 31 features.
# Fitting estimator with 481 features.
# Fitting estimator with 451 features.
# Fitting estimator with 421 features.
# Fitting estimator with 391 features.
# Fitting estimator with 361 features.
# Fitting estimator with 331 features.
# Fitting estimator with 301 features.
# Fitting estimator with 271 features.
# Fitting estimator with 241 features.
# ...

# %%
del Xscaggnonan

# %%
print('Optimal number of features:', rfe.n_features_)

for col in Xscaggnonan.columns[rfe.ranking_ == 1]:
    print(col)
# Out:
# Optimal number of features: 301
# score
# TransactionAmt_by_card_id_ws1d_to_mean
# TransactionAmt_by_card_id_ws1d_to_std
# TransactionAmt_by_card_id_ws2d_to_mean
# TransactionAmt_by_card_id_ws2d_to_std
# TransactionAmt_by_card_id_ws3d_to_mean
# TransactionAmt_by_card_id_ws3d_to_std
# TransactionAmt_by_card_id_ws7d_to_mean
# TransactionAmt_by_card_id_ws7d_to_std
# TransactionAmt_by_card_id_ws30d_to_mean
# TransactionAmt_by_card_id_ws30d_to_std
# TransactionAmt_by_card_id_ws5_to_mean
# TransactionAmt_by_card_id_ws5_to_std
# TransactionAmt_by_card_id_ws10_to_mean
# TransactionAmt_by_card_id_ws10_to_std
# TransactionAmt_by_card_id_ws100_to_mean
# TransactionAmt_by_card_id_ws100_to_std
# C1_by_card_id_ws1d_to_mean
# C1_by_card_id_ws1d_to_std
# C1_by_card_id_ws2d_to_mean
# C1_by_card_id_ws2d_to_std
# C1_by_card_id_ws3d_to_mean
# C1_by_card_id_ws3d_to_std
# C1_by_card_id_ws7d_to_mean
# C1_by_card_id_ws7d_to_std
# C1_by_card_id_ws30d_to_mean
# C1_by_card_id_ws30d_to_std
# ...

# %%
lst_time_aggs = []
for col in Xscaggnonan.columns[rfe.ranking_ == 1]:
    lst_time_aggs.append(col)

pd.DataFrame(lst_time_aggs).to_csv('list_time_aggs_v1.csv')

# %%
import os
allpkl = os.listdir('f:/my/Prog/kaggle/Baydin/Data/agg1')

# %%
# timeaggs = pd.DataFrame(index=y.index)
i=0
for item in allpkl:
    if item[0] == 'V':
        i+=1
        print(i, item)
        temp = pd.read_pickle(f'f:/my/Prog/kaggle/Baydin/Data/agg1/{item}')
        temp = reduce_mem_usage(temp)
        temp.to_pickle(f'f:/my/Prog/kaggle/Baydin/Data/agg2/{item}')
        
#         timeaggs = pd.concat([timeaggs, reduce_mem_usage(pd.read_pickle(f'f:/my/Prog/kaggle/Baydin/Data/agg1/{item}'))], axis=1)
# Out:
# 1 V10.pkl
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 2 V100.pkl
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 3 V11.pkl
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 4 V12.pkl
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 5 V126.pkl
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 6 V127.pkl
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 7 V128.pkl
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 8 V13.pkl
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 9 V130.pkl
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 10 V131.pkl
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 11 V138.pkl
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 12 V139.pkl
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 13 V140.pkl
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 14 V143.pkl
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# 15 V145.pkl
# Mem. usage decreased to 92.08 Mb (35.3% reduction)
# ...

# %%
timeaggs = pd.DataFrame(index=y.index)
i=0

for item in allpkl:
    if item[0] == 'V':
        i+=1
        print(i, item)
        
        timeaggs = pd.concat([timeaggs, pd.read_pickle(f'f:/my/Prog/kaggle/Baydin/Data/agg2/{item}')], axis=1)
# Out:
# 1 V10.pkl
# 2 V100.pkl
# 3 V11.pkl
# 4 V12.pkl
# 5 V126.pkl
# 6 V127.pkl
# 7 V128.pkl
# 8 V13.pkl
# 9 V130.pkl
# 10 V131.pkl
# 11 V138.pkl
# 12 V139.pkl
# 13 V140.pkl
# 14 V143.pkl
# 15 V145.pkl
# 16 V146.pkl
# 17 V147.pkl
# 18 V149.pkl
# 19 V150.pkl
# 20 V151.pkl
# 21 V152.pkl
# 22 V154.pkl
# 23 V156.pkl
# 24 V158.pkl
# 25 V159.pkl
# 26 V160.pkl
# 27 V161.pkl
# 28 V162.pkl
# 29 V163.pkl
# 30 V164.pkl
# 31 V165.pkl
# 32 V166.pkl
# 33 V167.pkl
# 34 V169.pkl
# 35 V17.pkl
# 36 V170.pkl
# 37 V171.pkl
# 38 V172.pkl
# 39 V173.pkl
# 40 V175.pkl
# 41 V176.pkl
# 42 V177.pkl
# 43 V178.pkl
# 44 V180.pkl
# 45 V182.pkl
# 46 V184.pkl
# 47 V187.pkl
# 48 V188.pkl
# 49 V189.pkl
# 50 V19.pkl
# 51 V195.pkl
# 52 V197.pkl
# 53 V20.pkl
# 54 V200.pkl
# 55 V201.pkl
# 56 V202.pkl
# 57 V203.pkl
# 58 V204.pkl
# 59 V205.pkl
# 60 V206.pkl
# 61 V207.pkl
# 62 V208.pkl
# 63 V209.pkl
# 64 V210.pkl
# 65 V212.pkl
# 66 V213.pkl
# 67 V214.pkl
# 68 V215.pkl
# 69 V216.pkl
# 70 V217.pkl
# 71 V219.pkl
# 72 V220.pkl
# ...

# %%
timeaggs.to_csv('first_hundred_Vs.csv')

# %%
Xscore = pd.read_csv('oof_best_submit.csv').set_index('TransactionID')
y = pd.read_pickle(f'f:/my/Prog/kaggle/Baydin/Data/y.pkl')
params = {'num_leaves': 491,
          'min_child_weight': 0.03454472573214212,
          'feature_fraction': 0.3797454081646243,
          'bagging_fraction': 0.4181193142567742,
          'min_data_in_leaf': 106,
          'objective': 'binary',
          'max_depth': -1,
          'learning_rate': 0.006883242363721497,
          "boosting_type": "gbdt",
          "bagging_seed": 11,
          "metric": 'auc',
          "verbosity": -1,
          'reg_alpha': 0.3899927210061127,
          'reg_lambda': 0.6485237330340494,
          'random_state': 47, 
         }

# %%
def Vs(pickle_name, Xscore, y, params, name):
    print('read X')
    X = pd.read_pickle(pickle_name)
    print('fill X')

    X.replace(np.inf, -999, inplace=True)
    X.replace(-np.inf, -999, inplace=True)
    X = X.fillna(-999)
    X = pd.concat([Xscore, X], axis=1)

    clf_2 = lgb.LGBMClassifier(**params)
    rfe_2 = RFECV(estimator=clf_2, step=10, cv=KFold(n_splits=5, shuffle=False), scoring='roc_auc', verbose=2)
    print('fit RFE')
    rfe_2.fit(X, y)

    print('Optimal number of features:', rfe_2.n_features_)

    lst_time_aggs = []
    for col in X.columns[rfe_2.ranking_ == 1]:
        lst_time_aggs.append(col)
    print('write to file')
    pd.DataFrame(lst_time_aggs).to_csv(f'list_time_aggs_V{name}.csv')

# %%
X = pd.read_csv('first_hundred_Vs.csv').set_index('TransactionID')
X = X.loc[:3577539]

# %%
# X1 = X.iloc[:, 100:200]
# X1.to_pickle('trainV100-200.pkl')

# X2 = X.iloc[:, 200:300]
# X2.to_pickle('trainV200-300.pkl')

# X3 = X.iloc[:, 300:400]
# X3.to_pickle('trainV300-400.pkl')

# X4 = X.iloc[:, 400:500]
# X4.to_pickle('trainV400-500.pkl')

# X5 = X.iloc[:, 500:600]
# X5.to_pickle('trainV500-600.pkl')

# X6 = X.iloc[:, 600:700]
# X6.to_pickle('trainV600-700.pkl')

# X7 = X.iloc[:, 700:800]
# X7.to_pickle('trainV700-800.pkl')

# X8 = X.iloc[:, 800:900]
# X8.to_pickle('trainV800-900.pkl')

# X9 = X.iloc[:, 900:1000]
# X9.to_pickle('trainV900-1000.pkl')

# X10 = X.iloc[:, 1000:1100]
# X10.to_pickle('trainV1000-1100.pkl')

# X11 = X.iloc[:, 1100:1200]
# X11.to_pickle('trainV1100-1200.pkl')

# X12 = X.iloc[:, 1200:1300]
# X12.to_pickle('trainV1200-1300.pkl')

# X13 = X.iloc[:, 1300:1400]
# X13.to_pickle('trainV1300-1400.pkl')

# X14 = X.iloc[:, 1400:]
# X14.to_pickle('trainV1400-end.pkl')

# %%
X0 = X.iloc[:, :100]
X0.to_pickle('trainV0-100.pkl')

# %%
del X

# %%
Vs('trainV0-100.pkl', Xscore, y, params, '100_test')
# Out:
# read X
# fill X
# fit RFE
# Fitting estimator with 101 features.
# Fitting estimator with 91 features.
# Fitting estimator with 81 features.
# Fitting estimator with 71 features.
# Fitting estimator with 61 features.
# Fitting estimator with 51 features.
# Fitting estimator with 41 features.
# Fitting estimator with 31 features.
# Fitting estimator with 21 features.
# Fitting estimator with 11 features.
# Fitting estimator with 101 features.
# Fitting estimator with 91 features.
# Fitting estimator with 81 features.
# Fitting estimator with 71 features.
# Fitting estimator with 61 features.
# Fitting estimator with 51 features.
# Fitting estimator with 41 features.
# Fitting estimator with 31 features.
# Fitting estimator with 21 features.
# Fitting estimator with 11 features.
# Fitting estimator with 101 features.
# Fitting estimator with 91 features.
# Fitting estimator with 81 features.
# Fitting estimator with 71 features.
# Fitting estimator with 61 features.
# ...

# %%
Vs('trainV100-200.pkl', Xscore, y, params, '200')
# Out:
# read X
# fill X
# fit RFE
# Fitting estimator with 101 features.
# Fitting estimator with 91 features.
# Fitting estimator with 81 features.
# Fitting estimator with 71 features.
# Fitting estimator with 61 features.
# Fitting estimator with 51 features.
# Fitting estimator with 41 features.
# Fitting estimator with 31 features.
# Fitting estimator with 21 features.
# Fitting estimator with 11 features.
# Fitting estimator with 101 features.
# Fitting estimator with 91 features.
# Fitting estimator with 81 features.
# Fitting estimator with 71 features.
# Fitting estimator with 61 features.
# Fitting estimator with 51 features.
# Fitting estimator with 41 features.
# Fitting estimator with 31 features.
# Fitting estimator with 21 features.
# Fitting estimator with 11 features.
# Fitting estimator with 101 features.
# Fitting estimator with 91 features.
# Fitting estimator with 81 features.
# Fitting estimator with 71 features.
# Fitting estimator with 61 features.
# ...

# %%
Vs('trainV200-300.pkl', Xscore, y, params, '300')
# Out:
# read X
# fill X
# fit RFE
# Fitting estimator with 101 features.
# Fitting estimator with 91 features.
# Fitting estimator with 81 features.
# Fitting estimator with 71 features.
# Fitting estimator with 61 features.
# Fitting estimator with 51 features.
# Fitting estimator with 41 features.
# Fitting estimator with 31 features.
# Fitting estimator with 21 features.
# Fitting estimator with 11 features.
# Fitting estimator with 101 features.
# Fitting estimator with 91 features.
# Fitting estimator with 81 features.
# Fitting estimator with 71 features.
# Fitting estimator with 61 features.
# Fitting estimator with 51 features.
# Fitting estimator with 41 features.
# Fitting estimator with 31 features.
# Fitting estimator with 21 features.
# Fitting estimator with 11 features.
# Fitting estimator with 101 features.
# Fitting estimator with 91 features.
# Fitting estimator with 81 features.
# Fitting estimator with 71 features.
# Fitting estimator with 61 features.
# ...

# %%
Vs('trainV300-400.pkl', Xscore, y, params, '400')
# Out:
# read X
# fill X
# fit RFE
# Fitting estimator with 101 features.
# Fitting estimator with 91 features.
# Fitting estimator with 81 features.
# Fitting estimator with 71 features.
# Fitting estimator with 61 features.
# Fitting estimator with 51 features.
# Fitting estimator with 41 features.
# Fitting estimator with 31 features.
# Fitting estimator with 21 features.
# Fitting estimator with 11 features.
# Fitting estimator with 101 features.
# Fitting estimator with 91 features.
# Fitting estimator with 81 features.
# Fitting estimator with 71 features.
# Fitting estimator with 61 features.
# Fitting estimator with 51 features.
# Fitting estimator with 41 features.
# Fitting estimator with 31 features.
# Fitting estimator with 21 features.
# Fitting estimator with 11 features.
# Fitting estimator with 101 features.
# Fitting estimator with 91 features.
# Fitting estimator with 81 features.
# Fitting estimator with 71 features.
# Fitting estimator with 61 features.
# ...

# %%
Vs('trainV400-500.pkl', Xscore, y, params, '500')
# Out:
# read X
# fill X
# fit RFE
# Fitting estimator with 101 features.
# Fitting estimator with 91 features.
# Fitting estimator with 81 features.
# Fitting estimator with 71 features.
# Fitting estimator with 61 features.
# Fitting estimator with 51 features.
# Fitting estimator with 41 features.
# Fitting estimator with 31 features.
# Fitting estimator with 21 features.
# Fitting estimator with 11 features.
# Fitting estimator with 101 features.
# Fitting estimator with 91 features.
# Fitting estimator with 81 features.
# Fitting estimator with 71 features.
# Fitting estimator with 61 features.
# Fitting estimator with 51 features.
# Fitting estimator with 41 features.
# Fitting estimator with 31 features.
# Fitting estimator with 21 features.
# Fitting estimator with 11 features.
# Fitting estimator with 101 features.
# Fitting estimator with 91 features.
# Fitting estimator with 81 features.
# Fitting estimator with 71 features.
# Fitting estimator with 61 features.
# ...

# %%
Vs('trainV500-600.pkl', Xscore, y, params, '600')
# Out:
# read X
# fill X
# fit RFE
# Fitting estimator with 101 features.
# Fitting estimator with 91 features.
# Fitting estimator with 81 features.
# Fitting estimator with 71 features.
# Fitting estimator with 61 features.
# Fitting estimator with 51 features.
# Fitting estimator with 41 features.
# Fitting estimator with 31 features.
# Fitting estimator with 21 features.
# Fitting estimator with 11 features.
# Fitting estimator with 101 features.
# Fitting estimator with 91 features.
# Fitting estimator with 81 features.
# Fitting estimator with 71 features.
# Fitting estimator with 61 features.
# Fitting estimator with 51 features.
# Fitting estimator with 41 features.
# Fitting estimator with 31 features.
# Fitting estimator with 21 features.
# Fitting estimator with 11 features.
# Fitting estimator with 101 features.
# Fitting estimator with 91 features.
# Fitting estimator with 81 features.
# Fitting estimator with 71 features.
# Fitting estimator with 61 features.
# ...

# %%
list_time_aggs_V700 = ['V172_by_card_id_ws30d_to_mean
V172_by_card_id_ws30d_to_std
V172_by_card_id_ws5_to_mean
V172_by_card_id_ws5_to_std
V172_by_card_id_ws10_to_mean
V172_by_card_id_ws10_to_std
V172_by_card_id_ws100_to_mean
V172_by_card_id_ws100_to_std
V173_by_card_id_ws1d_to_mean
V173_by_card_id_ws1d_to_std
V173_by_card_id_ws2d_to_mean
V173_by_card_id_ws3d_to_mean
V173_by_card_id_ws30d_to_mean
V173_by_card_id_ws30d_to_std
V173_by_card_id_ws5_to_std
V173_by_card_id_ws10_to_std
V173_by_card_id_ws100_to_mean
V175_by_card_id_ws1d_to_mean
V175_by_card_id_ws1d_to_std
V175_by_card_id_ws2d_to_mean
V175_by_card_id_ws2d_to_std
V175_by_card_id_ws3d_to_mean
V175_by_card_id_ws3d_to_std
V175_by_card_id_ws7d_to_mean
V175_by_card_id_ws7d_to_std
V175_by_card_id_ws30d_to_mean
V175_by_card_id_ws30d_to_std
V175_by_card_id_ws5_to_mean
V175_by_card_id_ws5_to_std
V175_by_card_id_ws10_to_mean
V175_by_card_id_ws10_to_std
V175_by_card_id_ws100_to_mean
V175_by_card_id_ws100_to_std
V176_by_card_id_ws1d_to_mean
V176_by_card_id_ws1d_to_std
V176_by_card_id_ws2d_to_mean
V176_by_card_id_ws2d_to_std
V176_by_card_id_ws3d_to_mean
V176_by_card_id_ws3d_to_std
V176_by_card_id_ws7d_to_mean
V176_by_card_id_ws7d_to_std
V176_by_card_id_ws30d_to_mean
V176_by_card_id_ws30d_to_std
V176_by_card_id_ws5_to_mean
V176_by_card_id_ws5_to_std
V176_by_card_id_ws10_to_mean
V176_by_card_id_ws10_to_std
V176_by_card_id_ws100_to_mean
V176_by_card_id_ws100_to_std
V177_by_card_id_ws1d_to_mean
V177_by_card_id_ws1d_to_std
V177_by_card_id_ws2d_to_mean
V177_by_card_id_ws3d_to_mean
V177_by_card_id_ws3d_to_std
V177_by_card_id_ws7d_to_mean
V177_by_card_id_ws30d_to_mean
V177_by_card_id_ws30d_to_std
V177_by_card_id_ws5_to_mean
V177_by_card_id_ws5_to_std
V177_by_card_id_ws10_to_mean
V177_by_card_id_ws10_to_std
V177_by_card_id_ws100_to_mean
V177_by_card_id_ws100_to_std
V178_by_card_id_ws1d_to_mean
V178_by_card_id_ws1d_to_std
V178_by_card_id_ws2d_to_mean
V178_by_card_id_ws2d_to_std
V178_by_card_id_ws3d_to_mean
V178_by_card_id_ws3d_to_std
V178_by_card_id_ws7d_to_mean
V178_by_card_id_ws7d_to_std
V178_by_card_id_ws30d_to_mean
V178_by_card_id_ws30d_to_std
V178_by_card_id_ws5_to_std
V178_by_card_id_ws10_to_mean
V178_by_card_id_ws10_to_std
V178_by_card_id_ws100_to_mean
V178_by_card_id_ws100_to_std
V180_by_card_id_ws1d_to_mean
V180_by_card_id_ws1d_to_std
V180_by_card_id_ws2d_to_mean
V180_by_card_id_ws2d_to_std
V180_by_card_id_ws3d_to_mean
V180_by_card_id_ws3d_to_std
V180_by_card_id_ws7d_to_mean
V180_by_card_id_ws7d_to_std
V180_by_card_id_ws30d_to_mean
V180_by_card_id_ws30d_to_std
V180_by_card_id_ws5_to_mean
V180_by_card_id_ws5_to_std

# %%
list_time_aggs_V900 = [V195_by_card_id_ws1d_to_std
V195_by_card_id_ws2d_to_mean
V195_by_card_id_ws2d_to_std
V195_by_card_id_ws3d_to_mean
V195_by_card_id_ws3d_to_std
V195_by_card_id_ws7d_to_mean
V195_by_card_id_ws7d_to_std
V195_by_card_id_ws30d_to_mean
V195_by_card_id_ws30d_to_std
V195_by_card_id_ws10_to_std
V195_by_card_id_ws100_to_mean
V195_by_card_id_ws100_to_std
V197_by_card_id_ws1d_to_std
V197_by_card_id_ws2d_to_mean
V197_by_card_id_ws2d_to_std
V197_by_card_id_ws3d_to_mean
V197_by_card_id_ws3d_to_std
V197_by_card_id_ws7d_to_mean
V197_by_card_id_ws7d_to_std
V197_by_card_id_ws30d_to_mean
V197_by_card_id_ws30d_to_std
V197_by_card_id_ws10_to_std
V197_by_card_id_ws100_to_mean
V197_by_card_id_ws100_to_std
V20_by_card_id_ws1d_to_mean
V20_by_card_id_ws1d_to_std
V20_by_card_id_ws2d_to_mean
V20_by_card_id_ws2d_to_std
V20_by_card_id_ws3d_to_mean
V20_by_card_id_ws3d_to_std
V20_by_card_id_ws7d_to_mean
V20_by_card_id_ws7d_to_std
V20_by_card_id_ws30d_to_mean
V20_by_card_id_ws30d_to_std
V20_by_card_id_ws5_to_mean
V20_by_card_id_ws5_to_std
V20_by_card_id_ws10_to_mean
V20_by_card_id_ws10_to_std
V20_by_card_id_ws100_to_mean
V20_by_card_id_ws100_to_std
V200_by_card_id_ws1d_to_mean
V200_by_card_id_ws1d_to_std
V200_by_card_id_ws2d_to_mean
V200_by_card_id_ws2d_to_std
V200_by_card_id_ws3d_to_mean
V200_by_card_id_ws3d_to_std
V200_by_card_id_ws7d_to_mean
V200_by_card_id_ws7d_to_std
V200_by_card_id_ws30d_to_mean
V200_by_card_id_ws30d_to_std
V200_by_card_id_ws5_to_std
V200_by_card_id_ws10_to_mean
V200_by_card_id_ws10_to_std
V200_by_card_id_ws100_to_mean
V200_by_card_id_ws100_to_std
V201_by_card_id_ws1d_to_mean
V201_by_card_id_ws1d_to_std
V201_by_card_id_ws2d_to_mean
V201_by_card_id_ws2d_to_std
V201_by_card_id_ws3d_to_mean
V201_by_card_id_ws3d_to_std
V201_by_card_id_ws7d_to_mean
V201_by_card_id_ws7d_to_std
V201_by_card_id_ws30d_to_mean
V201_by_card_id_ws30d_to_std
V201_by_card_id_ws5_to_mean
V201_by_card_id_ws5_to_std
V201_by_card_id_ws10_to_mean
V201_by_card_id_ws10_to_std
V201_by_card_id_ws100_to_mean
V201_by_card_id_ws100_to_std
V202_by_card_id_ws1d_to_mean
V202_by_card_id_ws1d_to_std
V202_by_card_id_ws2d_to_mean
V202_by_card_id_ws2d_to_std
V202_by_card_id_ws3d_to_mean
V202_by_card_id_ws7d_to_mean
V202_by_card_id_ws7d_to_std
V202_by_card_id_ws30d_to_mean
V202_by_card_id_ws30d_to_std
V202_by_card_id_ws5_to_mean
V202_by_card_id_ws5_to_std
V202_by_card_id_ws10_to_mean
V202_by_card_id_ws10_to_std
V202_by_card_id_ws100_to_mean
V202_by_card_id_ws100_to_std
V203_by_card_id_ws1d_to_mean
V203_by_card_id_ws1d_to_std
V203_by_card_id_ws2d_to_mean
V203_by_card_id_ws2d_to_std

# %%
list_time_aggs_V1000 = []

# %%
list_time_aggs_V1100 = []

# %%
list_time_aggs_V1200 = ['V216_by_card_id_ws10_to_mean',
'V216_by_card_id_ws10_to_std',
'V216_by_card_id_ws100_to_mean',
'V216_by_card_id_ws100_to_std',
'V217_by_card_id_ws1d_to_mean',
'V217_by_card_id_ws1d_to_std',
'V217_by_card_id_ws2d_to_mean',
'V217_by_card_id_ws2d_to_std',
'V217_by_card_id_ws3d_to_mean',
'V217_by_card_id_ws3d_to_std',
'V217_by_card_id_ws7d_to_mean',
'V217_by_card_id_ws7d_to_std',
'V217_by_card_id_ws30d_to_mean',
'V217_by_card_id_ws30d_to_std',
'V217_by_card_id_ws5_to_mean',
'V217_by_card_id_ws5_to_std',
'V217_by_card_id_ws10_to_mean',
'V217_by_card_id_ws10_to_std',
'V217_by_card_id_ws100_to_mean',
'V217_by_card_id_ws100_to_std',
'V219_by_card_id_ws1d_to_mean',
'V219_by_card_id_ws1d_to_std',
'V219_by_card_id_ws2d_to_mean',
'V219_by_card_id_ws2d_to_std',
'V219_by_card_id_ws3d_to_mean',
'V219_by_card_id_ws3d_to_std',
'V219_by_card_id_ws7d_to_mean',
'V219_by_card_id_ws7d_to_std',
'V219_by_card_id_ws30d_to_mean',
'V219_by_card_id_ws30d_to_std',
'V219_by_card_id_ws5_to_mean',
'V219_by_card_id_ws5_to_std',
'V219_by_card_id_ws10_to_mean',
'V219_by_card_id_ws10_to_std',
'V219_by_card_id_ws100_to_mean',
'V219_by_card_id_ws100_to_std',
'V220_by_card_id_ws1d_to_mean',
'V220_by_card_id_ws1d_to_std',
'V220_by_card_id_ws7d_to_mean',
'V220_by_card_id_ws30d_to_mean',
'V220_by_card_id_ws30d_to_std',
'V220_by_card_id_ws5_to_std',
'V220_by_card_id_ws10_to_mean',
'V220_by_card_id_ws10_to_std',
'V220_by_card_id_ws100_to_mean',
'V220_by_card_id_ws100_to_std',
'V221_by_card_id_ws1d_to_mean',
'V221_by_card_id_ws1d_to_std',
'V221_by_card_id_ws2d_to_mean',
'V221_by_card_id_ws2d_to_std',
'V221_by_card_id_ws3d_to_mean',
'V221_by_card_id_ws3d_to_std',
'V221_by_card_id_ws7d_to_mean',
'V221_by_card_id_ws7d_to_std',
'V221_by_card_id_ws30d_to_mean',
'V221_by_card_id_ws30d_to_std',
'V221_by_card_id_ws5_to_mean',
'V221_by_card_id_ws5_to_std',
'V221_by_card_id_ws10_to_mean',
'V221_by_card_id_ws10_to_std',
'V221_by_card_id_ws100_to_mean',
'V221_by_card_id_ws100_to_std',
'V222_by_card_id_ws1d_to_mean',
'V222_by_card_id_ws1d_to_std',
'V222_by_card_id_ws2d_to_mean',
'V222_by_card_id_ws2d_to_std',
'V222_by_card_id_ws3d_to_mean',
'V222_by_card_id_ws3d_to_std',
'V222_by_card_id_ws7d_to_mean',
'V222_by_card_id_ws7d_to_std',
'V222_by_card_id_ws30d_to_mean',
'V222_by_card_id_ws30d_to_std',
'V222_by_card_id_ws5_to_mean',
'V222_by_card_id_ws5_to_std',
'V222_by_card_id_ws10_to_mean',
'V222_by_card_id_ws10_to_std',
'V222_by_card_id_ws100_to_mean',
'V222_by_card_id_ws100_to_std',
'V223_by_card_id_ws1d_to_mean',
'V223_by_card_id_ws1d_to_std',
'V223_by_card_id_ws2d_to_mean',
'V223_by_card_id_ws2d_to_std',
'V223_by_card_id_ws3d_to_mean',
'V223_by_card_id_ws7d_to_mean',
'V223_by_card_id_ws7d_to_std',
'V223_by_card_id_ws30d_to_mean',
'V223_by_card_id_ws30d_to_std',
'V223_by_card_id_ws10_to_std',
'V223_by_card_id_ws100_to_mean',
'V223_by_card_id_ws100_to_std',]

# %%
list_time_aggs_V1300 = ['V224_by_card_id_ws1d_to_mean',
'V224_by_card_id_ws1d_to_std',
'V224_by_card_id_ws2d_to_mean',
'V224_by_card_id_ws2d_to_std',
'V224_by_card_id_ws3d_to_mean',
'V224_by_card_id_ws3d_to_std',
'V224_by_card_id_ws7d_to_mean',
'V224_by_card_id_ws7d_to_std',
'V224_by_card_id_ws30d_to_mean',
'V224_by_card_id_ws30d_to_std',
'V224_by_card_id_ws5_to_mean',
'V224_by_card_id_ws5_to_std',
'V224_by_card_id_ws10_to_mean',
'V224_by_card_id_ws10_to_std',
'V224_by_card_id_ws100_to_mean',
'V224_by_card_id_ws100_to_std',
'V225_by_card_id_ws1d_to_mean',
'V225_by_card_id_ws1d_to_std',
'V225_by_card_id_ws2d_to_mean',
'V225_by_card_id_ws3d_to_mean',
'V225_by_card_id_ws3d_to_std',
'V225_by_card_id_ws7d_to_mean',
'V225_by_card_id_ws7d_to_std',
'V225_by_card_id_ws30d_to_mean',
'V225_by_card_id_ws30d_to_std',
'V225_by_card_id_ws5_to_mean',
'V225_by_card_id_ws10_to_mean',
'V225_by_card_id_ws10_to_std',
'V225_by_card_id_ws100_to_mean',
'V225_by_card_id_ws100_to_std',
'V226_by_card_id_ws3d_to_mean',
'V226_by_card_id_ws7d_to_mean',
'V226_by_card_id_ws7d_to_std',
'V226_by_card_id_ws30d_to_mean',
'V226_by_card_id_ws30d_to_std',
'V226_by_card_id_ws10_to_std',
'V226_by_card_id_ws100_to_mean',
'V226_by_card_id_ws100_to_std',
'V227_by_card_id_ws1d_to_mean',
'V227_by_card_id_ws1d_to_std',
'V227_by_card_id_ws2d_to_mean',
'V227_by_card_id_ws2d_to_std',
'V227_by_card_id_ws3d_to_mean',
'V227_by_card_id_ws3d_to_std',
'V227_by_card_id_ws7d_to_mean',
'V227_by_card_id_ws7d_to_std',
'V227_by_card_id_ws30d_to_mean',
'V227_by_card_id_ws30d_to_std',
'V227_by_card_id_ws5_to_mean',
'V227_by_card_id_ws5_to_std',
'V227_by_card_id_ws10_to_mean',
'V227_by_card_id_ws10_to_std',
'V227_by_card_id_ws100_to_mean',
'V227_by_card_id_ws100_to_std',
'V228_by_card_id_ws1d_to_mean',
'V228_by_card_id_ws1d_to_std',
'V228_by_card_id_ws2d_to_mean',
'V228_by_card_id_ws2d_to_std',
'V228_by_card_id_ws3d_to_mean',
'V228_by_card_id_ws3d_to_std',
'V228_by_card_id_ws7d_to_mean',
'V228_by_card_id_ws7d_to_std',
'V228_by_card_id_ws30d_to_mean',
'V228_by_card_id_ws30d_to_std',
'V228_by_card_id_ws5_to_mean',
'V228_by_card_id_ws5_to_std',
'V228_by_card_id_ws10_to_mean',
'V228_by_card_id_ws10_to_std',
'V228_by_card_id_ws100_to_mean',
'V228_by_card_id_ws100_to_std',
'V229_by_card_id_ws1d_to_mean',
'V229_by_card_id_ws1d_to_std',
'V229_by_card_id_ws2d_to_mean',
'V229_by_card_id_ws2d_to_std',
'V229_by_card_id_ws3d_to_mean',
'V229_by_card_id_ws3d_to_std',
'V229_by_card_id_ws7d_to_mean',
'V229_by_card_id_ws7d_to_std',
'V229_by_card_id_ws30d_to_mean',
'V229_by_card_id_ws30d_to_std',
'V229_by_card_id_ws5_to_mean',
'V229_by_card_id_ws5_to_std',
'V229_by_card_id_ws10_to_mean',
'V229_by_card_id_ws10_to_std',
'V229_by_card_id_ws100_to_mean',
'V229_by_card_id_ws100_to_std',
'V231_by_card_id_ws1d_to_mean',
'V231_by_card_id_ws1d_to_std',
'V231_by_card_id_ws2d_to_mean',
'V231_by_card_id_ws2d_to_std']

# %%
list_time_aggs_V1400 = ['V231_by_card_id_ws3d_to_mean',
'V231_by_card_id_ws3d_to_std',
'V231_by_card_id_ws7d_to_mean',
'V231_by_card_id_ws7d_to_std',
'V231_by_card_id_ws30d_to_mean',
'V231_by_card_id_ws30d_to_std',
'V231_by_card_id_ws5_to_mean',
'V231_by_card_id_ws5_to_std',
'V231_by_card_id_ws10_to_mean',
'V231_by_card_id_ws10_to_std',
'V231_by_card_id_ws100_to_mean',
'V231_by_card_id_ws100_to_std',
'V233_by_card_id_ws1d_to_mean',
'V233_by_card_id_ws1d_to_std',
'V233_by_card_id_ws2d_to_mean',
'V233_by_card_id_ws2d_to_std',
'V233_by_card_id_ws3d_to_mean',
'V233_by_card_id_ws3d_to_std',
'V233_by_card_id_ws7d_to_mean',
'V233_by_card_id_ws7d_to_std',
'V233_by_card_id_ws30d_to_mean',
'V233_by_card_id_ws30d_to_std',
'V233_by_card_id_ws5_to_mean',
'V233_by_card_id_ws5_to_std',
'V233_by_card_id_ws10_to_mean',
'V233_by_card_id_ws10_to_std',
'V233_by_card_id_ws100_to_mean',
'V233_by_card_id_ws100_to_std',
'V234_by_card_id_ws1d_to_mean',
'V234_by_card_id_ws1d_to_std',
'V234_by_card_id_ws2d_to_mean',
'V234_by_card_id_ws2d_to_std',
'V234_by_card_id_ws3d_to_mean',
'V234_by_card_id_ws3d_to_std',
'V234_by_card_id_ws7d_to_mean',
'V234_by_card_id_ws7d_to_std',
'V234_by_card_id_ws30d_to_mean',
'V234_by_card_id_ws30d_to_std',
'V234_by_card_id_ws5_to_mean',
'V234_by_card_id_ws5_to_std',
'V234_by_card_id_ws10_to_mean',
'V234_by_card_id_ws10_to_std',
'V234_by_card_id_ws100_to_mean',
'V234_by_card_id_ws100_to_std',
'V238_by_card_id_ws1d_to_std',
'V238_by_card_id_ws2d_to_std',
'V238_by_card_id_ws7d_to_mean',
'V238_by_card_id_ws7d_to_std',
'V238_by_card_id_ws30d_to_mean',
'V238_by_card_id_ws30d_to_std',
'V238_by_card_id_ws5_to_std',
'V238_by_card_id_ws10_to_mean',
'V238_by_card_id_ws10_to_std',
'V238_by_card_id_ws100_to_mean',
'V238_by_card_id_ws100_to_std',
'V239_by_card_id_ws1d_to_std',
'V239_by_card_id_ws2d_to_mean',
'V239_by_card_id_ws3d_to_mean',
'V239_by_card_id_ws30d_to_mean',
'V239_by_card_id_ws30d_to_std',
'V239_by_card_id_ws5_to_mean',
'V239_by_card_id_ws5_to_std',
'V239_by_card_id_ws10_to_mean',
'V239_by_card_id_ws10_to_std',
'V239_by_card_id_ws100_to_mean',
'V239_by_card_id_ws100_to_std',
'V242_by_card_id_ws1d_to_mean',
'V242_by_card_id_ws1d_to_std',
'V242_by_card_id_ws2d_to_mean',
'V242_by_card_id_ws2d_to_std',
'V242_by_card_id_ws3d_to_mean',
'V242_by_card_id_ws3d_to_std',
'V242_by_card_id_ws7d_to_mean',
'V242_by_card_id_ws7d_to_std',
'V242_by_card_id_ws30d_to_mean',
'V242_by_card_id_ws30d_to_std',
'V242_by_card_id_ws5_to_mean',
'V242_by_card_id_ws5_to_std',
'V242_by_card_id_ws10_to_mean',
'V242_by_card_id_ws10_to_std',
'V242_by_card_id_ws100_to_mean',
'V242_by_card_id_ws100_to_std',
'V243_by_card_id_ws1d_to_mean',
'V243_by_card_id_ws1d_to_std',
'V243_by_card_id_ws2d_to_mean',
'V243_by_card_id_ws2d_to_std',
'V243_by_card_id_ws3d_to_mean',
'V243_by_card_id_ws3d_to_std',
'V243_by_card_id_ws7d_to_mean',
'V243_by_card_id_ws7d_to_std']

# %%
list_time_aggs_V1500 = ['V243_by_card_id_ws30d_to_mean',
'V243_by_card_id_ws30d_to_std',
'V243_by_card_id_ws5_to_std',
'V243_by_card_id_ws10_to_std',
'V243_by_card_id_ws100_to_mean',
'V243_by_card_id_ws100_to_std',
'V244_by_card_id_ws1d_to_std',
'V244_by_card_id_ws2d_to_std',
'V244_by_card_id_ws3d_to_mean',
'V244_by_card_id_ws3d_to_std',
'V244_by_card_id_ws7d_to_mean',
'V244_by_card_id_ws7d_to_std',
'V244_by_card_id_ws30d_to_mean',
'V244_by_card_id_ws30d_to_std',
'V244_by_card_id_ws5_to_std',
'V244_by_card_id_ws10_to_std',
'V244_by_card_id_ws100_to_mean',
'V244_by_card_id_ws100_to_std',
'V245_by_card_id_ws2d_to_std',
'V245_by_card_id_ws3d_to_std',
'V245_by_card_id_ws7d_to_mean',
'V245_by_card_id_ws7d_to_std',
'V245_by_card_id_ws30d_to_mean',
'V245_by_card_id_ws30d_to_std',
'V245_by_card_id_ws5_to_std',
'V245_by_card_id_ws10_to_mean',
'V245_by_card_id_ws10_to_std',
'V245_by_card_id_ws100_to_mean',
'V245_by_card_id_ws100_to_std',
'V246_by_card_id_ws1d_to_std',
'V246_by_card_id_ws2d_to_std',
'V246_by_card_id_ws3d_to_std',
'V246_by_card_id_ws7d_to_mean',
'V246_by_card_id_ws7d_to_std',
'V246_by_card_id_ws30d_to_mean',
'V246_by_card_id_ws30d_to_std',
'V246_by_card_id_ws10_to_std',
'V246_by_card_id_ws100_to_mean',
'V246_by_card_id_ws100_to_std',
'V247_by_card_id_ws2d_to_std',
'V247_by_card_id_ws7d_to_std',
'V247_by_card_id_ws30d_to_mean',
'V247_by_card_id_ws30d_to_std',
'V247_by_card_id_ws100_to_mean',
'V247_by_card_id_ws100_to_std',
'V249_by_card_id_ws2d_to_std',
'V249_by_card_id_ws3d_to_std',
'V249_by_card_id_ws7d_to_mean',
'V249_by_card_id_ws7d_to_std',
'V249_by_card_id_ws30d_to_mean',
'V249_by_card_id_ws30d_to_std',
'V249_by_card_id_ws10_to_std',
'V249_by_card_id_ws100_to_mean',
'V249_by_card_id_ws100_to_std',
'V251_by_card_id_ws1d_to_std',
'V251_by_card_id_ws2d_to_mean',
'V251_by_card_id_ws2d_to_std',
'V251_by_card_id_ws3d_to_mean',
'V251_by_card_id_ws3d_to_std',
'V251_by_card_id_ws7d_to_mean',
'V251_by_card_id_ws7d_to_std',
'V251_by_card_id_ws30d_to_mean',
'V251_by_card_id_ws30d_to_std',
'V251_by_card_id_ws10_to_mean',
'V251_by_card_id_ws10_to_std',
'V251_by_card_id_ws100_to_mean',
'V251_by_card_id_ws100_to_std',
'V253_by_card_id_ws2d_to_std',
'V253_by_card_id_ws3d_to_std',
'V253_by_card_id_ws7d_to_mean',
'V253_by_card_id_ws7d_to_std',
'V253_by_card_id_ws30d_to_mean',
'V253_by_card_id_ws30d_to_std',
'V253_by_card_id_ws10_to_std',
'V253_by_card_id_ws100_to_mean',
'V253_by_card_id_ws100_to_std',
'V256_by_card_id_ws2d_to_std',
'V256_by_card_id_ws3d_to_std',
'V256_by_card_id_ws7d_to_mean',
'V256_by_card_id_ws7d_to_std',
'V256_by_card_id_ws30d_to_mean',
'V256_by_card_id_ws30d_to_std',
'V256_by_card_id_ws10_to_std',
'V256_by_card_id_ws100_to_mean',
'V256_by_card_id_ws100_to_std',
'V257_by_card_id_ws1d_to_std',
'V257_by_card_id_ws2d_to_std',
'V257_by_card_id_ws3d_to_std',
'V257_by_card_id_ws7d_to_mean',
'V257_by_card_id_ws7d_to_std',
'V257_by_card_id_ws30d_to_mean',
'V257_by_card_id_ws30d_to_std',
'V257_by_card_id_ws5_to_std',
'V257_by_card_id_ws10_to_mean',
'V257_by_card_id_ws10_to_std',
'V257_by_card_id_ws100_to_mean',
'V257_by_card_id_ws100_to_std',
'V258_by_card_id_ws1d_to_std',
'V258_by_card_id_ws2d_to_mean',
'V258_by_card_id_ws2d_to_std',
'V258_by_card_id_ws3d_to_mean',
'V258_by_card_id_ws3d_to_std',
'V258_by_card_id_ws7d_to_mean',
'V258_by_card_id_ws7d_to_std',
'V258_by_card_id_ws30d_to_mean',
'V258_by_card_id_ws30d_to_std',
'V258_by_card_id_ws5_to_std',
'V258_by_card_id_ws10_to_mean',
'V258_by_card_id_ws10_to_std',
'V258_by_card_id_ws100_to_mean',
'V258_by_card_id_ws100_to_std',
'V259_by_card_id_ws1d_to_std',
'V259_by_card_id_ws2d_to_mean',
'V259_by_card_id_ws3d_to_mean',
'V259_by_card_id_ws3d_to_std',
'V259_by_card_id_ws7d_to_mean',
'V259_by_card_id_ws7d_to_std',
'V259_by_card_id_ws30d_to_mean',
'V259_by_card_id_ws30d_to_std',
'V259_by_card_id_ws5_to_std',
'V259_by_card_id_ws10_to_mean',
'V259_by_card_id_ws10_to_std',
'V259_by_card_id_ws100_to_mean',
'V259_by_card_id_ws100_to_std']
